# %%
import pandas as pd

# %%
clinical_data =  pd.read_csv('../../preprocessing_18_dec/clinical_data_AD_NCI_preprocessed_removed_batch_0.csv')

# %%
clinical_data
# Out:
#      specimenID  Batch  educ  cogdx  race        pmi  age_at_visit_max  \
# 0     23_120411    6.0  18.0    4.0   1.0   6.416667         90.000000
# 1    591_120522    2.0  12.0    4.0   1.0   5.200000         90.000000
# 2    691_120605    5.0  14.0    1.0   1.0   4.833333         90.000000
# 3    588_120522    1.0  18.0    1.0   1.0   4.400000         90.000000
# 4    604_120523    2.0  20.0    4.0   1.0  17.833333         90.000000
# ..          ...    ...   ...    ...   ...        ...               ...
# 159  677_120604    4.0  23.0    1.0   1.0  18.666667         71.720739
# 160  142_120419    6.0  23.0    1.0   1.0   7.000000         71.603012
# 161  120_120418    5.0  26.0    1.0   1.0   4.083333         71.482546
# 162  483_120515    1.0  10.0    1.0   1.0   5.433333         70.510609
# 163  174_120424    5.0  12.0    1.0   1.0   5.000000         66.959617
#
#      ceradsc  braaksc  msex  Category
# 0        1.0      4.0   0.0         1
# ...

# %%
count_matrix_mrn = pd.read_csv('../Data/GRN_input/Preprocessed(just_before_GRN_pipeline)/count_matrix_mrn.csv', index_col= 0)

# %%
count_matrix_mrn = count_matrix_mrn[list(clinical_data.specimenID)]

# %%
AD_count_matrix = count_matrix_mrn[list(clinical_data[clinical_data.Category == 1]['specimenID'])]

# %%
AD_count_matrix
# Out:
#             23_120411  591_120522  604_120523  545_120516  364_120502  \
# gene_name
# TSPAN6     186.219072  148.783568  111.437481  130.201294  293.148548
# DPM1       369.092891  294.127054  343.200096  306.515546  296.060619
# SCYL3      137.155364  129.003094  179.804034  161.395354  150.457036
# C1orf112    42.373202   25.800619   42.387263   42.044168   33.974169
# FGR        233.052611  205.544929  142.886096  249.552480  186.372587
# ...               ...         ...         ...         ...         ...
# ADORA3     100.357584   51.601237   47.856587   88.157126   80.567316
# FRG1CP     443.803537  272.626538  351.404082  527.586494  388.276222
# BISPR       37.912865   30.960742   24.611959   40.687904   30.091407
# GTF2IP12   113.738595   79.121897   72.468546   85.444599  111.629414
# LBHD2       18.956432   33.540804   88.192853   40.687904   27.179336
#
#            705_120605  711_120531  602_120523  229_120425  708_120531  ...  \
# ...

# %%
NCI_count_matrix = count_matrix_mrn[list(clinical_data[clinical_data.Category == 0]['specimenID'])]

# %%
NCI_count_matrix
# Out:
#            691_120605  588_120522  680_120604  274_120430  713_120531  \
# gene_name
# TSPAN6     217.108458  275.061412  177.935775  231.777588  145.660979
# DPM1       325.662687  350.679670  338.077973  388.356225  312.130670
# SCYL3      134.053544  113.427387  157.332686  104.042384  127.824941
# C1orf112    31.327730   29.302075   50.571220   32.963924   22.295048
# FGR        121.668163  150.291287  284.697241  212.205258  132.283951
# ...               ...         ...         ...         ...         ...
# ADORA3      88.883328  113.427387   78.666343   87.560422   14.863365
# FRG1CP     335.133861  332.720334  278.141712  348.181443  387.933833
# BISPR       38.613249   25.521162   24.349106   49.445885   23.781384
# GTF2IP12    74.312291  103.975104   76.793335   75.198951   73.573658
# LBHD2       65.569668   24.575934   15.920569   18.542207   45.333264
#
#            460_120514   04_120405  285_120430  647_120529  950_131107  ...  \
# ...

# %%
count_matrix_mrn[list(clinical_data[clinical_data.Category == 0]['specimenID'])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ld/fhtyx4qs4mg6bw9chm___tsh0000gn/T/ipykernel_28449/2558303566.py in ?()
# ----> 1 count_matrix_mrn[list(clinical_data[clinical_data.Category == 0 * clinical_data.msex == 0.0]['specimenID'])]
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
clinical_data.Category == 0 * clinical_data.msex == 0.0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ld/fhtyx4qs4mg6bw9chm___tsh0000gn/T/ipykernel_28449/2332244640.py in ?()
# ----> 1 clinical_data.Category == 0 * clinical_data.msex == 0.0
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
clinical_data.Category == 0 + clinical_data.msex == 0.0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ld/fhtyx4qs4mg6bw9chm___tsh0000gn/T/ipykernel_28449/3184356117.py in ?()
# ----> 1 clinical_data.Category == 0 + clinical_data.msex == 0.0
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
clinical_data[clinical_data.Category == 0][clinical_data.msex == 0.0]
# Out:
# /var/folders/ld/fhtyx4qs4mg6bw9chm___tsh0000gn/T/ipykernel_28449/2434289081.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   clinical_data[clinical_data.Category == 0][clinical_data.msex == 0.0]
#      specimenID  Batch  educ  cogdx  race        pmi  age_at_visit_max  \
# 2    691_120605    5.0  14.0    1.0   1.0   4.833333         90.000000
# 3    588_120522    1.0  18.0    1.0   1.0   4.400000         90.000000
# 13   680_120604    2.0  23.0    1.0   1.0   4.166667         90.000000
# 23   460_120514    5.0  12.0    1.0   1.0   3.666667         90.000000
# 25    04_120405    1.0  18.0    1.0   1.0   3.250000         90.000000
# 38   285_120430    2.0  15.0    1.0   1.0   5.333333         90.000000
# 46   647_120529    2.0  12.0    1.0   1.0   6.250000         90.000000
# 49   950_131107    8.0  18.0    1.0   1.0   5.916667         90.000000
# 50   146_120419    6.0  16.0    1.0   1.0   2.583333         90.000000
# ...

# %%
x = clinical_data[clinical_data.Category == 0]
x[x.msex == 0.0]
# Out:
#      specimenID  Batch  educ  cogdx  race        pmi  age_at_visit_max  \
# 2    691_120605    5.0  14.0    1.0   1.0   4.833333         90.000000
# 3    588_120522    1.0  18.0    1.0   1.0   4.400000         90.000000
# 13   680_120604    2.0  23.0    1.0   1.0   4.166667         90.000000
# 23   460_120514    5.0  12.0    1.0   1.0   3.666667         90.000000
# 25    04_120405    1.0  18.0    1.0   1.0   3.250000         90.000000
# 38   285_120430    2.0  15.0    1.0   1.0   5.333333         90.000000
# 46   647_120529    2.0  12.0    1.0   1.0   6.250000         90.000000
# 49   950_131107    8.0  18.0    1.0   1.0   5.916667         90.000000
# 50   146_120419    6.0  16.0    1.0   1.0   2.583333         90.000000
# 56   605_120523    2.0  10.0    1.0   1.0   3.750000         89.278576
# 60    74_120417    1.0  20.0    1.0   1.0   2.750000         88.947296
# 69   481_120514    3.0  12.0    1.0   1.0  26.000000         88.506502
# ...

# %%
x
# Out:
#      specimenID  Batch  educ  cogdx  race        pmi  age_at_visit_max  \
# 2    691_120605    5.0  14.0    1.0   1.0   4.833333         90.000000
# 3    588_120522    1.0  18.0    1.0   1.0   4.400000         90.000000
# 13   680_120604    2.0  23.0    1.0   1.0   4.166667         90.000000
# 15   274_120430    1.0  12.0    1.0   1.0   9.833333         90.000000
# 21   713_120531    2.0  14.0    1.0   1.0   7.483333         90.000000
# ..          ...    ...   ...    ...   ...        ...               ...
# 159  677_120604    4.0  23.0    1.0   1.0  18.666667         71.720739
# 160  142_120419    6.0  23.0    1.0   1.0   7.000000         71.603012
# 161  120_120418    5.0  26.0    1.0   1.0   4.083333         71.482546
# 162  483_120515    1.0  10.0    1.0   1.0   5.433333         70.510609
# 163  174_120424    5.0  12.0    1.0   1.0   5.000000         66.959617
#
#      ceradsc  braaksc  msex  Category
# 2        4.0      3.0   0.0         0
# ...
