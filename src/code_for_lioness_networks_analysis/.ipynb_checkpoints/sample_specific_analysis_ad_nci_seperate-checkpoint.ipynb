# %%
import pandas as pd
import os
from tqdm import tqdm

# %%
len(os.listdir('../../data_preprocessed/grn_output/ad_nci_seperate_network/lioness/ad/'))
# Out:
# 87

# %%
##  AD

'''
raw_single_sample_network_dir_path = '../../data_preprocessed/grn_output/ad_nci_seperate_network/lioness/ad/'
preprocessed_single_sample_network_dir_path = '../../data_preprocessed/grn_output/ad_nci_seperate_network/lioness/ad_preprocessed/'




for i in os.listdir(raw_single_sample_network_dir_path ):
  
    data = pd.read_csv(raw_single_sample_network_dir_path + i, index_col=0)
    break



from tqdm import tqdm
col_1 = []
col_2 = []
values = []
for i in tqdm(os.listdir(raw_single_sample_network_dir_path)):
    if i == 'panda_obj.pkl' or i == 'output_panda_df.csv':
        continue
    data = pd.read_csv(raw_single_sample_network_dir_path + i, index_col=0)
    
    for i in tqdm(data.iterrows()):
        col_1.extend([i[0] for l in range(len(data.columns))])
        col_2.extend(data.columns)
        values.extend(i[1].tolist())
    preprocessed_data = pd.DataFrame([col_1,col_2,values]).T
    break



list_of_genes = data.columns
list_of_tf = data.index.tolist()




for m in tqdm(os.listdir(raw_single_sample_network_dir_path)):
    col_1 = []
    col_2 = []
    values = []
    #if m in os.listdir(preprocessed_single_sample_network_dir_path):
    #    continue
        
    
    if m == 'panda_obj.pkl' or m == 'output_panda_df.csv':
        continue
    if m == 'output_panda_df.csv':
        continue
    print(m)
    if 'csv' in m:
        data = pd.read_csv(raw_single_sample_network_dir_path + m, index_col=0)
        list_of_genes = data.columns
        list_of_tf = data.index.tolist()
        for i in list_of_tf:
            for j in list_of_genes:
                if data.loc[i,j] >= 3.71036:
                    col_1.append(i)
                    col_2.append(j)
                    values.append(data.loc[i,j])
                 
        preprocessed_data = pd.DataFrame([col_1, col_2, values]).T
        preprocessed_data.to_csv(preprocessed_single_sample_network_dir_path  + m, index= False)



'''
# Out:
#   0%|                                                    | 0/87 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 95it [00:00, 941.43it/s]
# 190it [00:00, 891.56it/s]
# 280it [00:00, 810.53it/s]
# 364it [00:00, 820.20it/s]
# 449it [00:00, 827.59it/s]
# 533it [00:00, 713.55it/s]
# 612it [00:00, 735.18it/s]
# 715it [00:00, 779.24it/s]
#   0%|                                                    | 0/87 [01:35<?, ?it/s]
#   0%|                                                    | 0/87 [00:00<?, ?it/s]
# lioness.427_120507.58.csv
#   1%|▍                                         | 1/87 [00:45<1:05:13, 45.51s/it]
# lioness.350_120501.44.csv
#   2%|▉                                         | 2/87 [01:31<1:04:57, 45.86s/it]
# lioness.497_120515.52.csv
#   3%|█▍                                        | 3/87 [02:17<1:03:56, 45.67s/it]
# lioness.231_120425.7.csv
#   5%|█▉                                        | 4/87 [03:02<1:03:12, 45.69s/it]
# lioness.24_120411.69.csv
#   6%|██▍                                       | 5/87 [03:48<1:02:30, 45.74s/it]
# lioness.520_120515.57.csv
#   7%|██▉                                       | 6/87 [04:34<1:01:54, 45.86s/it]
# lioness.202_120424.0.csv
#   8%|███▍                                      | 7/87 [05:20<1:01:09, 45.87s/it]
# lioness.429_120507.56.csv
#   9%|███▊                                      | 8/87 [06:07<1:00:40, 46.08s/it]
# lioness.568_120521.82.csv
#  10%|████▌                                       | 9/87 [06:52<59:47, 46.00s/it]
# lioness.237_120426.37.csv
#  11%|████▉                                      | 10/87 [07:38<59:03, 46.02s/it]
# lioness.952_131107.75.csv
#  13%|█████▍                                     | 11/87 [08:25<58:30, 46.20s/it]
# lioness.591_120522.48.csv
#  14%|█████▉                                     | 12/87 [09:11<57:44, 46.20s/it]
# lioness.28_120411.27.csv
#  15%|██████▏                                  | 13/87 [10:13<1:02:35, 50.75s/it]
# lioness.243_120426.29.csv
#  16%|██████▉                                    | 14/87 [10:58<59:48, 49.15s/it]
# lioness.326_120501.77.csv
#  17%|███████▍                                   | 15/87 [11:44<57:44, 48.12s/it]
# lioness.12_120410.13.csv
#  18%|███████▉                                   | 16/87 [12:30<56:13, 47.51s/it]
# lioness.76_120417.81.csv
#  20%|████████▍                                  | 17/87 [13:15<54:45, 46.94s/it]
# lioness.228_120425.20.csv
#  21%|████████▉                                  | 18/87 [14:01<53:31, 46.55s/it]
# lioness.02_120405.3.csv
#  22%|█████████▍                                 | 19/87 [14:47<52:30, 46.33s/it]
# lioness.635_120524.11.csv
#  23%|█████████▉                                 | 20/87 [15:33<51:36, 46.22s/it]
# lioness.229_120425.50.csv
#  24%|██████████▍                                | 21/87 [16:19<50:40, 46.06s/it]
# lioness.554_120517.80.csv
#  25%|██████████▊                                | 22/87 [17:04<49:45, 45.93s/it]
# lioness.459_120514.24.csv
#  26%|███████████▎                               | 23/87 [17:50<49:01, 45.96s/it]
# lioness.364_120502.30.csv
#  28%|███████████▊                               | 24/87 [18:36<48:07, 45.84s/it]
# lioness.424_120507.4.csv
#  29%|████████████▎                              | 25/87 [19:22<47:30, 45.98s/it]
# lioness.695_120605.49.csv
#  30%|████████████▊                              | 26/87 [20:07<46:22, 45.62s/it]
# lioness.355_120501.70.csv
#  31%|█████████████▎                             | 27/87 [20:53<45:40, 45.68s/it]
# lioness.318_120501.62.csv
#  32%|█████████████▊                             | 28/87 [21:38<44:49, 45.59s/it]
# lioness.280_120430.63.csv
#  33%|██████████████▎                            | 29/87 [22:24<44:15, 45.78s/it]
# lioness.321_120501.68.csv
#  34%|██████████████▊                            | 30/87 [23:09<43:17, 45.57s/it]
# lioness.602_120523.71.csv
#  36%|███████████████▎                           | 31/87 [23:56<42:42, 45.75s/it]
# lioness.649_120529.32.csv
#  37%|███████████████▊                           | 32/87 [24:41<41:57, 45.77s/it]
# lioness.494_120515.16.csv
#  38%|████████████████▎                          | 33/87 [25:27<41:05, 45.65s/it]
# lioness.705_120605.64.csv
#  39%|████████████████▊                          | 34/87 [26:13<40:32, 45.89s/it]
# lioness.706_120605.5.csv
#  40%|█████████████████▎                         | 35/87 [26:59<39:45, 45.88s/it]
# lioness.444_120507.45.csv
#  41%|█████████████████▊                         | 36/87 [27:45<38:58, 45.84s/it]
# lioness.545_120516.12.csv
#  43%|██████████████████▎                        | 37/87 [28:30<37:57, 45.54s/it]
# lioness.604_120523.23.csv
#  44%|██████████████████▊                        | 38/87 [29:15<37:11, 45.54s/it]
# lioness.310_120430.46.csv
#  45%|███████████████████▎                       | 39/87 [30:01<36:27, 45.58s/it]
# lioness.482_120514.22.csv
#  46%|███████████████████▊                       | 40/87 [30:48<36:09, 46.16s/it]
# lioness.607_120523.31.csv
#  47%|████████████████████▎                      | 41/87 [31:37<35:56, 46.87s/it]
# lioness.628_120524.79.csv
#  48%|████████████████████▊                      | 42/87 [32:24<35:05, 46.79s/it]
# lioness.104_120418.6.csv
#  49%|█████████████████████▎                     | 43/87 [33:11<34:24, 46.91s/it]
# lioness.637_120524.67.csv
#  51%|█████████████████████▋                     | 44/87 [33:57<33:27, 46.68s/it]
# lioness.550_120517.2.csv
#  52%|██████████████████████▏                    | 45/87 [34:45<33:03, 47.23s/it]
# lioness.703_120605.38.csv
#  53%|██████████████████████▋                    | 46/87 [35:33<32:20, 47.34s/it]
# lioness.197_120424.65.csv
#  54%|███████████████████████▏                   | 47/87 [36:21<31:40, 47.51s/it]
# lioness.606_120523.84.csv
#  55%|███████████████████████▋                   | 48/87 [37:09<30:57, 47.62s/it]
# lioness.663_120530.28.csv
#  56%|████████████████████████▏                  | 49/87 [37:56<30:10, 47.65s/it]
# lioness.292_120430.76.csv
#  57%|████████████████████████▋                  | 50/87 [38:43<29:10, 47.30s/it]
# lioness.511_120515.34.csv
#  59%|█████████████████████████▏                 | 51/87 [39:29<28:10, 46.95s/it]
# lioness.289_120430.59.csv
#  60%|█████████████████████████▋                 | 52/87 [40:16<27:20, 46.86s/it]
# lioness.407_120503.19.csv
#  61%|██████████████████████████▏                | 53/87 [41:00<26:12, 46.24s/it]
# lioness.704_120605.15.csv
#  62%|██████████████████████████▋                | 54/87 [41:46<25:19, 46.06s/it]
# lioness.193_120424.74.csv
#  63%|███████████████████████████▏               | 55/87 [42:34<24:48, 46.50s/it]
# lioness.553_120517.53.csv
#  64%|███████████████████████████▋               | 56/87 [43:22<24:17, 47.01s/it]
# lioness.531_120516.55.csv
#  66%|████████████████████████████▏              | 57/87 [44:10<23:37, 47.25s/it]
# lioness.286_120430.14.csv
#  67%|████████████████████████████▋              | 58/87 [44:59<23:05, 47.76s/it]
# lioness.181_120424.33.csv
#  68%|█████████████████████████████▏             | 59/87 [45:47<22:23, 47.96s/it]
# lioness.70_120417.25.csv
#  69%|█████████████████████████████▋             | 60/87 [46:36<21:40, 48.18s/it]
# lioness.942_131101.36.csv
#  70%|██████████████████████████████▏            | 61/87 [47:24<20:55, 48.29s/it]
# lioness.434_120507.17.csv
#  71%|██████████████████████████████▋            | 62/87 [48:14<20:20, 48.81s/it]
# lioness.196_120424.18.csv
#  72%|███████████████████████████████▏           | 63/87 [49:03<19:29, 48.71s/it]
# lioness.304_120430.40.csv
#  74%|███████████████████████████████▋           | 64/87 [49:50<18:32, 48.37s/it]
# lioness.721_120531.60.csv
#  75%|████████████████████████████████▏          | 65/87 [50:38<17:38, 48.13s/it]
# lioness.363_120502.73.csv
#  76%|████████████████████████████████▌          | 66/87 [51:25<16:46, 47.92s/it]
# lioness.646_120524.41.csv
#  77%|█████████████████████████████████          | 67/87 [52:14<16:00, 48.04s/it]
# lioness.309_120430.10.csv
#  78%|█████████████████████████████████▌         | 68/87 [53:02<15:13, 48.06s/it]
# lioness.469_120514.72.csv
#  79%|██████████████████████████████████         | 69/87 [53:49<14:22, 47.90s/it]
# lioness.711_120531.83.csv
#  80%|██████████████████████████████████▌        | 70/87 [54:35<13:24, 47.35s/it]
# lioness.214_120425.35.csv
#  82%|███████████████████████████████████        | 71/87 [55:22<12:34, 47.18s/it]
# lioness.537_120516.78.csv
#  83%|███████████████████████████████████▌       | 72/87 [56:09<11:43, 46.93s/it]
# lioness.56_120417.86.csv
#  84%|████████████████████████████████████       | 73/87 [56:55<10:56, 46.89s/it]
# lioness.617_120524.43.csv
#  85%|████████████████████████████████████▌      | 74/87 [57:43<10:11, 47.02s/it]
# lioness.173_120424.21.csv
#  86%|█████████████████████████████████████      | 75/87 [58:29<09:22, 46.91s/it]
# lioness.232_120425.51.csv
#  87%|█████████████████████████████████████▌     | 76/87 [59:16<08:35, 46.91s/it]
# lioness.36_120416.66.csv
#  89%|████████████████████████████████████▎    | 77/87 [1:00:03<07:48, 46.90s/it]
# lioness.34_120416.8.csv
#  90%|████████████████████████████████████▊    | 78/87 [1:00:50<07:01, 46.84s/it]
# lioness.323_120501.1.csv
#  91%|█████████████████████████████████████▏   | 79/87 [1:01:37<06:15, 46.97s/it]
# lioness.384_120503.61.csv
#  92%|█████████████████████████████████████▋   | 80/87 [1:02:27<05:35, 47.90s/it]
# lioness.630_120524.42.csv
#  93%|██████████████████████████████████████▏  | 81/87 [1:03:14<04:45, 47.55s/it]
# lioness.708_120531.47.csv
#  94%|██████████████████████████████████████▋  | 82/87 [1:04:01<03:56, 47.39s/it]
# lioness.77_120417.9.csv
#  95%|███████████████████████████████████████  | 83/87 [1:04:48<03:09, 47.45s/it]
# lioness.23_120411.54.csv
#  97%|███████████████████████████████████████▌ | 84/87 [1:05:36<02:21, 47.33s/it]
# lioness.715_120531.39.csv
#  98%|████████████████████████████████████████ | 85/87 [1:06:22<01:33, 46.99s/it]
# lioness.420_120507.26.csv
#  99%|████████████████████████████████████████▌| 86/87 [1:07:08<00:46, 46.72s/it]
# lioness.689_120604.85.csv
# 100%|█████████████████████████████████████████| 87/87 [1:07:55<00:00, 46.84s/it]

# %%
##  NCI
'''


raw_single_sample_network_dir_path = '../../data_preprocessed/grn_output/ad_nci_seperate_network/lioness/nci/'
preprocessed_single_sample_network_dir_path = '../../data_preprocessed/grn_output/ad_nci_seperate_network/lioness/nci_preprocessed/'



for i in os.listdir(raw_single_sample_network_dir_path ):
  
    data = pd.read_csv(raw_single_sample_network_dir_path + i, index_col=0)
    break



from tqdm import tqdm
col_1 = []
col_2 = []
values = []
for i in tqdm(os.listdir(raw_single_sample_network_dir_path)):
    if i == 'panda_obj.pkl' or i == 'output_panda_df.csv':
        continue
    data = pd.read_csv(raw_single_sample_network_dir_path + i, index_col=0)
    
    for i in tqdm(data.iterrows()):
        col_1.extend([i[0] for l in range(len(data.columns))])
        col_2.extend(data.columns)
        values.extend(i[1].tolist())
    preprocessed_data = pd.DataFrame([col_1,col_2,values]).T
    break



list_of_genes = data.columns
list_of_tf = data.index.tolist()




for m in tqdm(os.listdir(raw_single_sample_network_dir_path)):
    col_1 = []
    col_2 = []
    values = []
    #if m in os.listdir(preprocessed_single_sample_network_dir_path):
     #   continue
        
    
    if m == 'panda_obj.pkl' or m == 'output_panda_df.csv':
        continue
    if m == 'output_panda_df.csv':
        continue
    print(m)
    if 'csv' in m:
        data = pd.read_csv(raw_single_sample_network_dir_path + m, index_col=0)
        list_of_genes = data.columns
        list_of_tf = data.index.tolist()
        for i in list_of_tf:
            for j in list_of_genes:
                if data.loc[i,j] >=  3.6737:
                    col_1.append(i)
                    col_2.append(j)
                    values.append(data.loc[i,j])
                 
        preprocessed_data = pd.DataFrame([col_1, col_2, values]).T
        preprocessed_data.to_csv(preprocessed_single_sample_network_dir_path  + m, index= False)




'''

# %% [markdown]
# # Data Loading

# %%
preprocessed_ad_single_sample_network_dir_path = '../../data_preprocessed/grn_output/ad_nci_seperate_network/lioness/ad_preprocessed/'
preprocessed_nci_single_sample_network_dir_path = '../../data_preprocessed/grn_output/ad_nci_seperate_network/lioness/nci_preprocessed/'

# %%
AD_data = pd.read_csv(preprocessed_ad_single_sample_network_dir_path +'lioness.427_120507.58.csv').rename(columns={'2':'lioness.427_120507.58.csv'.split('.')[1]})

for i in tqdm(os.listdir(preprocessed_ad_single_sample_network_dir_path)):
    if i.split('.')[1] in AD_data.columns:
        continue
    if 'csv' in i:
        df = pd.read_csv(preprocessed_ad_single_sample_network_dir_path + i).rename(columns={'2':i.split('.')[1]})
        AD_data = pd.merge(AD_data,df, on=['0','1'])
# Out:
# 100%|███████████████████████████████████████████| 87/87 [00:19<00:00,  4.46it/s]

# %%
os.listdir(preprocessed_nci_single_sample_network_dir_path )
# Out:
# ['lioness.713_120531.47.csv',
#  'lioness.951_131107.41.csv',
#  'lioness.534_120516.45.csv',
#  'lioness.950_131107.5.csv',
#  'lioness.298_120430.34.csv',
#  'lioness.508_120515.61.csv',
#  'lioness.567_120521.31.csv',
#  'lioness.408_120503.33.csv',
#  'lioness.340_120501.9.csv',
#  'lioness.290_120430.51.csv',
#  'lioness.498_120515.65.csv',
#  'lioness.461_120514.54.csv',
#  'lioness.481_120514.52.csv',
#  'lioness.142_120419.3.csv',
#  'lioness.587_120522.17.csv',
#  'lioness.647_120529.13.csv',
#  'lioness.213_120425.58.csv',
#  'lioness.285_120430.12.csv',
#  'lioness.345_120501.64.csv',
#  'lioness.57_120417.20.csv',
#  'lioness.82_120417.38.csv',
#  'lioness.04_120405.60.csv',
#  'lioness.501_120515.46.csv',
#  'lioness.829_130725.37.csv',
#  'lioness.502_120515.24.csv',
#  'lioness.182_120424.29.csv',
#  'lioness.812_130702.6.csv',
#  'lioness.483_120515.21.csv',
#  'lioness.564_120517.2.csv',
#  'lioness.11_120410.49.csv',
#  'lioness.122_120418.23.csv',
#  'lioness.120_120418.26.csv',
#  'lioness.605_120523.19.csv',
#  'lioness.626_120524.48.csv',
#  'lioness.938_131101.1.csv',
#  'lioness.174_120424.59.csv',
#  'lioness.314_120501.42.csv',
#  'lioness.633_120524.62.csv',
#  'lioness.88_120417.22.csv',
#  'lioness.352_120501.0.csv',
#  'lioness.787_130530.39.csv',
#  'lioness.460_120514.32.csv',
#  'lioness.691_120605.14.csv',
#  'lioness.551_120517.44.csv',
#  'lioness.283_120430.8.csv',
#  'lioness.245_120426.53.csv',
#  'lioness.329_120501.35.csv',
#  'lioness.331_120501.30.csv',
#  'lioness.547_120516.25.csv',
#  'lioness.418_120507.55.csv',
#  'lioness.274_120430.40.csv',
#  'lioness.588_120522.57.csv',
#  'lioness.253_120426.11.csv',
#  'lioness.505_120515.36.csv',
#  'lioness.638_120524.43.csv',
#  'lioness.146_120419.63.csv',
#  'lioness.456_120507.4.csv',
#  'lioness.45_120416.18.csv',
#  'lioness.677_120604.28.csv',
#  'lioness.65_120417.15.csv',
#  'lioness.680_120604.27.csv',
#  'lioness.74_120417.50.csv',
#  'lioness.152_120419.66.csv',
#  'lioness.360_120502.7.csv',
#  'lioness.72_120417.16.csv',
#  'lioness.470_120514.10.csv',
#  'lioness.386_120503.56.csv']

# %%
NCI_data = pd.read_csv(preprocessed_nci_single_sample_network_dir_path +'lioness.713_120531.47.csv').rename(columns={'2':'lioness.713_120531.47.csv'.split('.')[1]})

for i in tqdm(os.listdir(preprocessed_nci_single_sample_network_dir_path)):
    if i.split('.')[1] in NCI_data.columns:
        continue
    if 'csv' in i:
        df = pd.read_csv(preprocessed_nci_single_sample_network_dir_path + i).rename(columns={'2':i.split('.')[1]})
        NCI_data = pd.merge(NCI_data,df, on=['0','1'])
# Out:
# 100%|███████████████████████████████████████████| 67/67 [00:14<00:00,  4.54it/s]

# %%
AD_data.index = AD_data['0'] + '_' + AD_data['1']
AD_data.drop(columns=['0','1'],inplace = True)
AD_data
# Out:
#                                  427_120507  350_120501  497_120515  \
# ENSG00000001167_ENSG00000109685    5.422789    5.582590    5.550316
# ENSG00000001167_ENSG00000107362    5.349803    5.752049    5.402732
# ENSG00000001167_ENSG00000159423    6.944132    6.990538    6.876413
# ENSG00000001167_ENSG00000187187    7.422239    7.454585    7.505677
# ENSG00000001167_ENSG00000082701    5.269524    5.272363    5.310407
# ...                                     ...         ...         ...
# ENSG00000278129_ENSG00000149311   13.323806   13.551514   13.455582
# ENSG00000278129_ENSG00000149308   13.651741   13.384342   13.417867
# ENSG00000278129_ENSG00000259291   13.322590   13.217686   13.624116
# ENSG00000278129_ENSG00000075826   15.400658   15.185094   15.313141
# ENSG00000278129_ENSG00000101040   13.149005   13.433854   13.069732
#
#                                  231_120425  24_120411  520_120515  \
# ENSG00000001167_ENSG00000109685    5.436518   5.477918    5.548920
# ENSG00000001167_ENSG00000107362    5.970177   5.579969    5.545492
# ENSG00000001167_ENSG00000159423    6.901820   7.081787    6.839790
# ENSG00000001167_ENSG00000187187    7.496206   7.481783    7.508017
# ENSG00000001167_ENSG00000082701    5.199323   5.234593    5.347205
# ...                                     ...        ...         ...
# ENSG00000278129_ENSG00000149311   13.484518  13.782081   13.830250
# ENSG00000278129_ENSG00000149308   13.138848  14.043145   13.598172
# ENSG00000278129_ENSG00000259291   13.552711  13.314662   13.600096
# ENSG00000278129_ENSG00000075826   15.302828  15.520248   15.504817
# ENSG00000278129_ENSG00000101040   13.260914  13.235256   13.224622
#
#                                  202_120424  429_120507  568_120521  \
# ENSG00000001167_ENSG00000109685    6.046489    7.273255    5.856410
# ENSG00000001167_ENSG00000107362    5.524647    7.371541    6.909634
# ENSG00000001167_ENSG00000159423    6.660703    4.564330    6.687014
# ENSG00000001167_ENSG00000187187    8.091021    5.815734    6.816783
# ENSG00000001167_ENSG00000082701    4.991966    6.463328    4.880796
# ...                                     ...         ...         ...
# ENSG00000278129_ENSG00000149311   13.832985   12.696918   13.087175
# ENSG00000278129_ENSG00000149308   13.447751   13.050427   13.273157
# ENSG00000278129_ENSG00000259291   13.381757   13.938124   13.432308
# ENSG00000278129_ENSG00000075826   15.394125   15.222350   15.275454
# ENSG00000278129_ENSG00000101040   13.269111   13.468500   13.284884
#
#                                  237_120426  ...  34_120416  323_120501  \
# ENSG00000001167_ENSG00000109685    5.458538  ...   7.035479    4.978047
# ENSG00000001167_ENSG00000107362    5.208306  ...   6.190164    5.540829
# ENSG00000001167_ENSG00000159423    7.031452  ...   5.906971    7.367776
# ENSG00000001167_ENSG00000187187    7.498840  ...   6.295673    7.262532
# ENSG00000001167_ENSG00000082701    5.210510  ...   6.167558    5.164574
# ...                                     ...  ...        ...         ...
# ENSG00000278129_ENSG00000149311   12.987033  ...  13.643625   13.820091
# ENSG00000278129_ENSG00000149308   13.042831  ...  13.304772   13.365571
# ENSG00000278129_ENSG00000259291   13.487628  ...  13.579048   13.126054
# ENSG00000278129_ENSG00000075826   15.302409  ...  14.903426   15.765718
# ENSG00000278129_ENSG00000101040   13.084374  ...  13.431703   13.556180
#
#                                  384_120503  630_120524  708_120531  \
# ENSG00000001167_ENSG00000109685    5.226350    5.794004    5.773878
# ENSG00000001167_ENSG00000107362    5.583583    5.759652    5.260326
# ENSG00000001167_ENSG00000159423    7.354607    6.683811    6.306993
# ENSG00000001167_ENSG00000187187    8.275199    7.424579    7.459808
# ENSG00000001167_ENSG00000082701    5.143659    5.702611    5.787845
# ...                                     ...         ...         ...
# ENSG00000278129_ENSG00000149311   14.347983   13.649700   13.699755
# ENSG00000278129_ENSG00000149308   13.219922   13.502602   13.330046
# ENSG00000278129_ENSG00000259291   11.702317   13.902514   13.227954
# ENSG00000278129_ENSG00000075826   14.325750   15.746934   15.301823
# ENSG00000278129_ENSG00000101040   14.903238   13.070853   14.047822
#
#                                  77_120417  23_120411  715_120531  420_120507  \
# ENSG00000001167_ENSG00000109685   6.562551   5.389306    5.295861    5.771548
# ENSG00000001167_ENSG00000107362   5.617084   5.433905    5.406885    6.530646
# ENSG00000001167_ENSG00000159423   5.897600   7.140654    7.122604    8.000273
# ENSG00000001167_ENSG00000187187   6.719548   7.478677    7.982371    8.699310
# ENSG00000001167_ENSG00000082701   5.607147   5.211411    4.986887    4.633950
# ...                                    ...        ...         ...         ...
# ENSG00000278129_ENSG00000149311  13.901009  13.704960   13.691899   13.739728
# ENSG00000278129_ENSG00000149308  14.842179  13.335939   13.413799   13.165613
# ENSG00000278129_ENSG00000259291  12.306634  13.353002   13.559723   13.362870
# ENSG00000278129_ENSG00000075826  16.321014  15.159812   14.998269   15.219113
# ENSG00000278129_ENSG00000101040  12.450501  13.362226   12.999160   13.549021
#
#                                  689_120604
# ENSG00000001167_ENSG00000109685    5.458670
# ENSG00000001167_ENSG00000107362    6.094826
# ENSG00000001167_ENSG00000159423    6.676154
# ENSG00000001167_ENSG00000187187    7.352844
# ENSG00000001167_ENSG00000082701    5.299784
# ...                                     ...
# ENSG00000278129_ENSG00000149311   13.844341
# ENSG00000278129_ENSG00000149308   13.400331
# ENSG00000278129_ENSG00000259291   13.377070
# ENSG00000278129_ENSG00000075826   15.219156
# ENSG00000278129_ENSG00000101040   13.116372
#
# [145574 rows x 87 columns]

# %%
NCI_data.index = NCI_data['0'] + '_' + NCI_data['1']
NCI_data.drop(columns=['0','1'],inplace = True)
NCI_data
# Out:
#                                  713_120531  951_131107  534_120516  \
# ENSG00000001167_ENSG00000176261    5.482700    5.559684    5.328263
# ENSG00000001167_ENSG00000140350    4.982475    5.268472    5.056994
# ENSG00000001167_ENSG00000139517    4.670906    5.577982    4.541473
# ENSG00000001167_ENSG00000130175    5.404625    5.039784    5.966988
# ENSG00000001167_ENSG00000132763    6.668552    7.620014    6.928177
# ...                                     ...         ...         ...
# ENSG00000278129_ENSG00000146281   13.407919   13.608027   13.227907
# ENSG00000278129_ENSG00000149311   13.579513   13.506464   13.196193
# ENSG00000278129_ENSG00000149308   13.468954   13.396475   13.954026
# ENSG00000278129_ENSG00000259291   13.402257   13.593209   13.433287
# ENSG00000278129_ENSG00000075826   15.274045   15.282260   15.514377
#
#                                  950_131107  298_120430  508_120515  \
# ENSG00000001167_ENSG00000176261    5.558828    5.234112    5.764225
# ENSG00000001167_ENSG00000140350    4.951359    4.641155    4.781434
# ENSG00000001167_ENSG00000139517    5.160953    5.674692    4.282357
# ENSG00000001167_ENSG00000130175    5.429527    5.448997    5.461276
# ENSG00000001167_ENSG00000132763    6.414171    5.395703    6.557029
# ...                                     ...         ...         ...
# ENSG00000278129_ENSG00000146281   14.391915   13.549009   12.006405
# ENSG00000278129_ENSG00000149311   13.461399   13.766703   12.441919
# ENSG00000278129_ENSG00000149308   13.570598   13.515806   12.230682
# ENSG00000278129_ENSG00000259291   13.741236   13.459474   13.860608
# ENSG00000278129_ENSG00000075826   15.448710   15.023314   16.028995
#
#                                  567_120521  408_120503  340_120501  \
# ENSG00000001167_ENSG00000176261    4.958463    5.549492    5.142077
# ENSG00000001167_ENSG00000140350    3.728474    5.032809    4.849961
# ENSG00000001167_ENSG00000139517    5.061684    5.294319    5.333695
# ENSG00000001167_ENSG00000130175    4.730063    5.469214    6.011928
# ENSG00000001167_ENSG00000132763    6.610947    6.684681    6.723611
# ...                                     ...         ...         ...
# ENSG00000278129_ENSG00000146281   13.739711   13.870628   13.617681
# ENSG00000278129_ENSG00000149311   13.481220   13.682145   14.360163
# ENSG00000278129_ENSG00000149308   13.424496   13.456604   13.519724
# ENSG00000278129_ENSG00000259291   13.401375   13.013666   12.994866
# ENSG00000278129_ENSG00000075826   15.476839   15.216776   15.439769
#
#                                  290_120430  ...  45_120416  677_120604  \
# ENSG00000001167_ENSG00000176261    5.423955  ...   5.539045    5.486246
# ENSG00000001167_ENSG00000140350    5.066636  ...   4.641848    4.917301
# ENSG00000001167_ENSG00000139517    5.182849  ...   5.138902    5.051557
# ENSG00000001167_ENSG00000130175    5.213447  ...   5.310032    5.421357
# ENSG00000001167_ENSG00000132763    6.637750  ...   6.582676    6.368325
# ...                                     ...  ...        ...         ...
# ENSG00000278129_ENSG00000146281   14.556836  ...  13.815204   13.900298
# ENSG00000278129_ENSG00000149311   13.905794  ...  13.861326   13.678813
# ENSG00000278129_ENSG00000149308   13.709119  ...  13.383097   13.604407
# ENSG00000278129_ENSG00000259291   13.598956  ...  13.947162   13.491532
# ENSG00000278129_ENSG00000075826   15.468871  ...  15.915617   15.433889
#
#                                  65_120417  680_120604  74_120417  152_120419  \
# ENSG00000001167_ENSG00000176261   5.495824    5.509237   5.682126    5.939890
# ENSG00000001167_ENSG00000140350   4.860898    4.327789   4.937663    7.987460
# ENSG00000001167_ENSG00000139517   5.169504    5.097622   5.208951    6.057974
# ENSG00000001167_ENSG00000130175   5.611544    5.238567   5.591549    5.091609
# ENSG00000001167_ENSG00000132763   5.864250    6.331151   6.526524    5.654648
# ...                                    ...         ...        ...         ...
# ENSG00000278129_ENSG00000146281  14.238177   13.738605  13.644225   12.071337
# ENSG00000278129_ENSG00000149311  14.054400   13.978881  13.474053   12.636080
# ENSG00000278129_ENSG00000149308  13.267566   13.527308  13.619648   14.694977
# ENSG00000278129_ENSG00000259291  13.561849   12.852991  13.357489   17.289715
# ENSG00000278129_ENSG00000075826  15.464810   15.220469  14.878867   19.255064
#
#                                  360_120502  72_120417  470_120514  386_120503
# ENSG00000001167_ENSG00000176261    5.470133   5.919201    5.088127    5.487017
# ENSG00000001167_ENSG00000140350    4.933812   4.901850    5.088763    4.872469
# ENSG00000001167_ENSG00000139517    4.922699   5.388184    5.884548    5.224092
# ENSG00000001167_ENSG00000130175    5.426514   5.538087    4.533787    5.320011
# ENSG00000001167_ENSG00000132763    6.704224   6.709261    7.736940    6.620601
# ...                                     ...        ...         ...         ...
# ENSG00000278129_ENSG00000146281   13.669115  13.824280   14.036683   14.066838
# ENSG00000278129_ENSG00000149311   13.386020  12.389482   13.614431   13.592434
# ENSG00000278129_ENSG00000149308   13.298863  13.189243   13.487149   13.202929
# ENSG00000278129_ENSG00000259291   13.600090  14.106542   13.737192   13.276627
# ENSG00000278129_ENSG00000075826   15.356346  15.681196   15.719278   14.963361
#
# [154135 rows x 67 columns]

# %%
common_edge = set(NCI_data.index).intersection(set(AD_data.index))
AD_data = AD_data.loc[list(common_edge),:]
NCI_data = NCI_data.loc[list(common_edge),:]

# %%
AD_data = AD_data.T
AD_data
# Out:
#             ENSG00000174652_ENSG00000198231  ENSG00000196378_ENSG00000065268  \
# 427_120507                         6.394178                         6.122934
# 350_120501                         6.412562                         6.318496
# 497_120515                         6.476437                         6.217154
# 231_120425                         6.527772                         6.004380
# 24_120411                          6.599608                         5.775097
# ...                                     ...                              ...
# 77_120417                          6.076628                         6.446484
# 23_120411                          6.533942                         6.252753
# 715_120531                         6.874199                         5.974861
# 420_120507                         6.603181                         6.131457
# 689_120604                         6.619254                         6.190001
#
#             ENSG00000025156_ENSG00000184545  ENSG00000122034_ENSG00000152380  \
# 427_120507                         7.790873                         7.721642
# 350_120501                         7.939735                         7.856669
# 497_120515                         7.811582                         7.255664
# 231_120425                         7.634794                         7.385915
# 24_120411                          7.683681                         7.267564
# ...                                     ...                              ...
# 77_120417                          6.840535                         6.916652
# 23_120411                          8.255896                         7.271510
# 715_120531                         7.603941                         7.571062
# 420_120507                         8.354008                         7.629701
# 689_120604                         7.892502                         7.806951
#
#             ENSG00000181135_ENSG00000106605  ENSG00000198176_ENSG00000188419  \
# 427_120507                         5.258129                        10.636912
# 350_120501                         5.182493                        10.424762
# 497_120515                         5.020076                        10.496389
# 231_120425                         5.126137                        10.600343
# 24_120411                          5.041860                        10.773260
# ...                                     ...                              ...
# 77_120417                          4.501292                        11.750500
# 23_120411                          5.174814                        10.209980
# 715_120531                         4.439732                        10.732898
# 420_120507                         5.322698                        10.321709
# 689_120604                         5.085056                        10.498998
#
#             ENSG00000001167_ENSG00000186432  ENSG00000054598_ENSG00000267370  \
# 427_120507                         5.178463                         6.330766
# 350_120501                         5.451730                         6.617430
# 497_120515                         5.456767                         5.657121
# 231_120425                         5.411098                         6.301380
# 24_120411                          5.412918                         7.409208
# ...                                     ...                              ...
# 77_120417                          5.445268                         5.930731
# 23_120411                          5.361647                         6.393522
# 715_120531                         4.783064                         6.465310
# 420_120507                         5.416540                         6.645251
# 689_120604                         5.284280                         6.334525
#
#             ENSG00000147124_ENSG00000088205  ENSG00000167635_ENSG00000177694  \
# 427_120507                         7.241927                        11.911459
# 350_120501                         7.040199                        11.687297
# 497_120515                         7.134129                        11.547512
# 231_120425                         7.101851                        11.930094
# 24_120411                          7.297268                        11.879619
# ...                                     ...                              ...
# 77_120417                         10.798342                        11.173235
# 23_120411                          7.149551                        12.049323
# 715_120531                         6.931772                        11.986352
# 420_120507                         7.261758                        11.393496
# 689_120604                         7.152252                        11.973006
#
#             ...  ENSG00000170365_ENSG00000188690  \
# 427_120507  ...                         6.545565
# 350_120501  ...                         6.943586
# 497_120515  ...                         6.492507
# 231_120425  ...                         7.431046
# 24_120411   ...                         6.860139
# ...         ...                              ...
# 77_120417   ...                         8.373757
# 23_120411   ...                         6.783667
# 715_120531  ...                         7.537204
# 420_120507  ...                         6.788510
# 689_120604  ...                         6.756892
#
#             ENSG00000137166_ENSG00000278873  ENSG00000171574_ENSG00000146859  \
# 427_120507                         7.718276                         9.683056
# 350_120501                         7.825023                         8.955410
# 497_120515                         7.654758                         8.459689
# 231_120425                         7.703107                         9.468503
# 24_120411                          7.690702                         8.937388
# ...                                     ...                              ...
# 77_120417                          6.381897                         9.730211
# 23_120411                          7.994580                         9.031307
# 715_120531                         7.347798                         9.013817
# 420_120507                         7.399161                         8.155277
# 689_120604                         7.337819                         8.951921
#
#             ENSG00000185630_ENSG00000279302  ENSG00000105722_ENSG00000064419  \
# 427_120507                        12.234568                         7.687873
# 350_120501                        11.413670                         7.719714
# 497_120515                        12.259038                         7.858682
# 231_120425                        12.207537                         7.732478
# 24_120411                         11.494260                         7.836052
# ...                                     ...                              ...
# 77_120417                         11.987047                         6.595965
# 23_120411                         12.205360                         7.853573
# 715_120531                        12.253942                         7.676427
# 420_120507                        11.949486                         8.154411
# 689_120604                        11.944896                         7.328970
#
#             ENSG00000005513_ENSG00000213891  ENSG00000151090_ENSG00000244754  \
# 427_120507                        11.635471                         5.990352
# 350_120501                        11.597850                         6.590043
# 497_120515                        11.735506                         5.229421
# 231_120425                        11.851610                         5.404873
# 24_120411                         12.716869                         6.509252
# ...                                     ...                              ...
# 77_120417                         12.149421                         9.162941
# 23_120411                         11.669525                         6.418351
# 715_120531                        11.685878                         5.989860
# 420_120507                        10.998335                         6.365374
# 689_120604                        12.132329                         6.642387
#
#             ENSG00000168310_ENSG00000279561  ENSG00000102349_ENSG00000158850  \
# 427_120507                         6.105093                         5.626414
# 350_120501                         5.874321                         5.978039
# 497_120515                         6.055918                         6.055321
# 231_120425                         6.180373                         6.092688
# 24_120411                          6.166031                         6.050775
# ...                                     ...                              ...
# 77_120417                          6.387338                         6.067257
# 23_120411                          6.255996                         5.995951
# 715_120531                         5.833271                         6.078889
# 420_120507                         6.329733                         5.892220
# 689_120604                         6.166784                         6.022419
#
#             ENSG00000188290_ENSG00000183579
# 427_120507                         5.818312
# 350_120501                         5.786968
# 497_120515                         5.710395
# 231_120425                         5.784983
# 24_120411                          5.791155
# ...                                     ...
# 77_120417                          5.920178
# 23_120411                          5.960596
# 715_120531                         5.894614
# 420_120507                         5.901194
# 689_120604                         5.876703
#
# [87 rows x 118489 columns]

# %%
NCI_data = NCI_data.T
NCI_data
# Out:
#             ENSG00000174652_ENSG00000198231  ENSG00000196378_ENSG00000065268  \
# 713_120531                         6.477955                         5.902072
# 951_131107                         6.542817                         6.303929
# 534_120516                         7.360047                         5.877117
# 950_131107                         6.542833                         6.107630
# 298_120430                         6.533948                         6.497895
# ...                                     ...                              ...
# 152_120419                         6.932700                         7.459821
# 360_120502                         6.547183                         6.290630
# 72_120417                          6.770045                         6.678281
# 470_120514                         6.583416                         6.194901
# 386_120503                         6.239564                         6.217369
#
#             ENSG00000025156_ENSG00000184545  ENSG00000122034_ENSG00000152380  \
# 713_120531                         7.121419                         7.434257
# 951_131107                         7.908639                         7.171463
# 534_120516                         7.001008                         7.232422
# 950_131107                         7.864052                         7.183189
# 298_120430                         7.801489                         7.501044
# ...                                     ...                              ...
# 152_120419                         9.567974                         4.846769
# 360_120502                         7.788670                         7.200175
# 72_120417                          9.319554                         7.520038
# 470_120514                         8.250550                         7.244817
# 386_120503                         7.889019                         7.770252
#
#             ENSG00000181135_ENSG00000106605  ENSG00000198176_ENSG00000188419  \
# 713_120531                         5.140467                        10.681281
# 951_131107                         5.087240                        10.609118
# 534_120516                         4.921121                         9.973031
# 950_131107                         5.253009                        10.948270
# 298_120430                         5.246206                        10.374669
# ...                                     ...                              ...
# 152_120419                         5.808681                        10.477833
# 360_120502                         5.322666                        10.537951
# 72_120417                          4.324676                        10.238579
# 470_120514                         5.228944                        10.558696
# 386_120503                         5.477230                        10.625251
#
#             ENSG00000001167_ENSG00000186432  ENSG00000054598_ENSG00000267370  \
# 713_120531                         5.358000                         6.118742
# 951_131107                         5.375376                         6.394354
# 534_120516                         5.113428                         4.745560
# 950_131107                         5.326871                         6.232319
# 298_120430                         5.682288                         6.470869
# ...                                     ...                              ...
# 152_120419                         6.363142                         8.136570
# 360_120502                         5.247141                         6.552199
# 72_120417                          4.814019                         4.725351
# 470_120514                         5.736175                         6.979856
# 386_120503                         5.373113                         6.406075
#
#             ENSG00000147124_ENSG00000088205  ENSG00000167635_ENSG00000177694  \
# 713_120531                         7.615517                        11.879453
# 951_131107                         7.079784                        12.306490
# 534_120516                         7.438580                        11.740888
# 950_131107                         7.092972                        12.231655
# 298_120430                         7.166615                        12.218711
# ...                                     ...                              ...
# 152_120419                         6.955157                        15.136136
# 360_120502                         6.980447                        12.077353
# 72_120417                          6.643471                        11.781038
# 470_120514                         7.078359                        11.792356
# 386_120503                         7.477228                        12.064919
#
#             ...  ENSG00000170365_ENSG00000188690  \
# 713_120531  ...                         6.729572
# 951_131107  ...                         6.813868
# 534_120516  ...                         6.724524
# 950_131107  ...                         6.794987
# 298_120430  ...                         6.681479
# ...         ...                              ...
# 152_120419  ...                         4.751137
# 360_120502  ...                         6.926788
# 72_120417   ...                         4.661276
# 470_120514  ...                         6.398907
# 386_120503  ...                         6.912737
#
#             ENSG00000137166_ENSG00000278873  ENSG00000171574_ENSG00000146859  \
# 713_120531                         7.674089                         8.880020
# 951_131107                         7.738500                         9.067086
# 534_120516                         8.048527                         9.614950
# 950_131107                         7.400740                         8.659979
# 298_120430                         7.590220                         9.273527
# ...                                     ...                              ...
# 152_120419                         8.976757                         3.699205
# 360_120502                         7.468472                         9.010273
# 72_120417                          8.353156                         8.354316
# 470_120514                         7.435881                         8.861829
# 386_120503                         7.566526                         9.034501
#
#             ENSG00000185630_ENSG00000279302  ENSG00000105722_ENSG00000064419  \
# 713_120531                        12.050551                         8.929017
# 951_131107                        11.770874                         7.354928
# 534_120516                        11.754859                        10.479874
# 950_131107                        12.175557                         8.001561
# 298_120430                        12.192347                         7.751462
# ...                                     ...                              ...
# 152_120419                        10.173251                         5.997146
# 360_120502                        12.452053                         7.558711
# 72_120417                         11.900505                         7.443180
# 470_120514                        11.903550                         7.457874
# 386_120503                        12.239770                         7.219823
#
#             ENSG00000005513_ENSG00000213891  ENSG00000151090_ENSG00000244754  \
# 713_120531                        11.774735                         6.471544
# 951_131107                        11.747685                         6.606737
# 534_120516                        11.898741                         5.500443
# 950_131107                        11.690613                         6.585350
# 298_120430                        11.888226                         6.595909
# ...                                     ...                              ...
# 152_120419                        12.328876                         6.123684
# 360_120502                        11.662923                         6.328104
# 72_120417                         11.464351                         6.796500
# 470_120514                        11.532890                         7.175874
# 386_120503                        11.874992                         6.366986
#
#             ENSG00000168310_ENSG00000279561  ENSG00000102349_ENSG00000158850  \
# 713_120531                         5.829061                         6.223210
# 951_131107                         5.984965                         6.064733
# 534_120516                         6.582437                         6.079999
# 950_131107                         6.061027                         5.683387
# 298_120430                         6.072875                         5.974081
# ...                                     ...                              ...
# 152_120419                         5.024053                         6.263054
# 360_120502                         6.015099                         5.939244
# 72_120417                          6.038638                         6.195236
# 470_120514                         6.078769                         5.635046
# 386_120503                         6.021051                         5.987022
#
#             ENSG00000188290_ENSG00000183579
# 713_120531                         5.722128
# 951_131107                         5.779940
# 534_120516                         5.143670
# 950_131107                         6.120369
# 298_120430                         5.779724
# ...                                     ...
# 152_120419                         5.728083
# 360_120502                         5.938982
# 72_120417                          5.394404
# 470_120514                         5.895278
# 386_120503                         5.837669
#
# [67 rows x 118489 columns]

# %%
combined = pd.concat([AD_data,NCI_data])

# %%
Label = ['AD' for i in range(len(AD_data))] + ['NCI' for i in range(len(NCI_data))]
Label
# Out:
# ['AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI',
#  'NCI']

# %%
combined['Label'] = Label

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# Generate sample data (replace this with your own DataFrame)


# Assuming your DataFrame contains only numeric values
# If not, you might need to preprocess your data accordingly

# Perform PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(combined.drop(columns = 'Label'))

# Create a new DataFrame with the principal components
pc_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

# Concatenate the principal components DataFrame with the original DataFrame
final_df = pd.concat([pc_df], axis=1)
final_df['Label'] = Label
final_df.index = combined.index


# Plot the PCA results
plt.figure(figsize=(8, 8))
sns.scatterplot(x='PC1', y='PC2', data=final_df, hue = Label)
plt.title('PCA Plot')
plt.xlabel('Principal Component 1 (PC1)')
plt.ylabel('Principal Component 2 (PC2)')
plt.show()

# %%
remove = final_df[final_df.PC1> 80].index.tolist()
remove
# Out:
# ['28_120411', '646_120524', '605_120523', '152_120419']

# %%
outlier_corrected_combined = combined[~combined.index.isin(remove)]

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# Generate sample data (replace this with your own DataFrame)


# Assuming your DataFrame contains only numeric values
# If not, you might need to preprocess your data accordingly

# Perform PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(outlier_corrected_combined .drop(columns = 'Label'))

# Create a new DataFrame with the principal components
pc_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

# Concatenate the principal components DataFrame with the original DataFrame
final_df = pd.concat([pc_df], axis=1)
final_df['Label'] = outlier_corrected_combined.Label.tolist()
final_df.index = outlier_corrected_combined.index
Label = outlier_corrected_combined.Label.tolist()

# Plot the PCA results
plt.figure(figsize=(8, 8))
sns.scatterplot(x='PC1', y='PC2', data=final_df, hue = Label )
plt.title('PCA Plot')
plt.xlabel('Principal Component 1 (PC1)')
plt.ylabel('Principal Component 2 (PC2)')
plt.show()

# %%
l = ['ENSG00000186300_ENSG00000215193',
 'ENSG00000166823_ENSG00000178199',
 'ENSG00000157557_ENSG00000121903',
 'ENSG00000138336_ENSG00000161381',
 'ENSG00000028277_ENSG00000039139',
 'ENSG00000081059_ENSG00000255561',
 'ENSG00000167981_ENSG00000143222',
 'ENSG00000198482_ENSG00000156219',
 'ENSG00000188786_ENSG00000083799',
 'ENSG00000168874_ENSG00000139197',
 'ENSG00000139800_ENSG00000150175',
 'ENSG00000079432_ENSG00000214425',
 'ENSG00000162992_ENSG00000139197',
 'ENSG00000256294_ENSG00000272576',
 'ENSG00000169635_ENSG00000234841',
 'ENSG00000125850_ENSG00000198783',
 'ENSG00000078900_ENSG00000062096',
 'ENSG00000120837_ENSG00000123179',
 'ENSG00000079432_ENSG00000188234',
 'ENSG00000188786_ENSG00000162384',
 'ENSG00000251369_ENSG00000265018',
 'ENSG00000234284_ENSG00000149089',
 'ENSG00000198429_ENSG00000107262',
 'ENSG00000188785_ENSG00000122641']

# %%
l = [
 'ENSG00000166823_ENSG00000178199',
 'ENSG00000157557_ENSG00000121903',

 'ENSG00000028277_ENSG00000039139',
 'ENSG00000081059_ENSG00000255561',
 'ENSG00000167981_ENSG00000143222',
 'ENSG00000198482_ENSG00000156219',
 'ENSG00000188786_ENSG00000083799',
 'ENSG00000168874_ENSG00000139197',
 'ENSG00000139800_ENSG00000150175',
 'ENSG00000079432_ENSG00000214425',
 'ENSG00000162992_ENSG00000139197',
 'ENSG00000256294_ENSG00000272576',
 'ENSG00000169635_ENSG00000234841',
 'ENSG00000125850_ENSG00000198783',
 'ENSG00000078900_ENSG00000062096',
 'ENSG00000120837_ENSG00000123179',
 'ENSG00000079432_ENSG00000188234',
 'ENSG00000188786_ENSG00000162384',
 'ENSG00000251369_ENSG00000265018',
 'ENSG00000234284_ENSG00000149089',
 'ENSG00000198429_ENSG00000107262',
 'ENSG00000188785_ENSG00000122641']

# %%
import pandas as pd
import random
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler


# Assuming your DataFrame contains only numeric values
# If not, you might need to preprocess your data accordingly

accuracies = []

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(outlier_corrected_combined.drop(columns='Label')[l], outlier_corrected_combined['Label'], test_size=0.2)

for i in tqdm(range(1)):

    #y_train = random.sample(list(y_train), len(list(y_train)))
    #y_test = random.sample(list(y_test), len(list(y_test)))
    # Initialize and train the logistic regression model
    #scaler = StandardScaler()
    #X_train_scaled = scaler.fit_transform(X_train)
    #X_test_scaled = scaler.transform(X_test)
    model = LogisticRegression(class_weight={'AD':1,'NCI':1})
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model performance
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)
    accuracies.append(accuracy)

print(f"Accuracy: {accuracy:.2f}")
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 140.92it/s]
# Accuracy: 0.97
#
# Confusion Matrix:
# [[16  1]
#  [ 0 13]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           AD       1.00      0.94      0.97        17
#          NCI       0.93      1.00      0.96        13
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
outlier_corrected_combined
# Out:
#             ENSG00000174652_ENSG00000198231  ENSG00000196378_ENSG00000065268  \
# 427_120507                         6.394178                         6.122934
# 350_120501                         6.412562                         6.318496
# 497_120515                         6.476437                         6.217154
# 231_120425                         6.527772                         6.004380
# 24_120411                          6.599608                         5.775097
# ...                                     ...                              ...
# 74_120417                          7.065234                         6.151323
# 360_120502                         6.547183                         6.290630
# 72_120417                          6.770045                         6.678281
# 470_120514                         6.583416                         6.194901
# 386_120503                         6.239564                         6.217369
#
#             ENSG00000025156_ENSG00000184545  ENSG00000122034_ENSG00000152380  \
# 427_120507                         7.790873                         7.721642
# 350_120501                         7.939735                         7.856669
# 497_120515                         7.811582                         7.255664
# 231_120425                         7.634794                         7.385915
# 24_120411                          7.683681                         7.267564
# ...                                     ...                              ...
# 74_120417                          7.708486                         7.637948
# 360_120502                         7.788670                         7.200175
# 72_120417                          9.319554                         7.520038
# 470_120514                         8.250550                         7.244817
# 386_120503                         7.889019                         7.770252
#
#             ENSG00000181135_ENSG00000106605  ENSG00000198176_ENSG00000188419  \
# 427_120507                         5.258129                        10.636912
# 350_120501                         5.182493                        10.424762
# 497_120515                         5.020076                        10.496389
# 231_120425                         5.126137                        10.600343
# 24_120411                          5.041860                        10.773260
# ...                                     ...                              ...
# 74_120417                          5.303501                        10.868139
# 360_120502                         5.322666                        10.537951
# 72_120417                          4.324676                        10.238579
# 470_120514                         5.228944                        10.558696
# 386_120503                         5.477230                        10.625251
#
#             ENSG00000001167_ENSG00000186432  ENSG00000054598_ENSG00000267370  \
# 427_120507                         5.178463                         6.330766
# 350_120501                         5.451730                         6.617430
# 497_120515                         5.456767                         5.657121
# 231_120425                         5.411098                         6.301380
# 24_120411                          5.412918                         7.409208
# ...                                     ...                              ...
# 74_120417                          5.217708                         6.122804
# 360_120502                         5.247141                         6.552199
# 72_120417                          4.814019                         4.725351
# 470_120514                         5.736175                         6.979856
# 386_120503                         5.373113                         6.406075
#
#             ENSG00000147124_ENSG00000088205  ENSG00000167635_ENSG00000177694  \
# 427_120507                         7.241927                        11.911459
# 350_120501                         7.040199                        11.687297
# 497_120515                         7.134129                        11.547512
# 231_120425                         7.101851                        11.930094
# 24_120411                          7.297268                        11.879619
# ...                                     ...                              ...
# 74_120417                          7.271213                        12.094598
# 360_120502                         6.980447                        12.077353
# 72_120417                          6.643471                        11.781038
# 470_120514                         7.078359                        11.792356
# 386_120503                         7.477228                        12.064919
#
#             ...  ENSG00000137166_ENSG00000278873  \
# 427_120507  ...                         7.718276
# 350_120501  ...                         7.825023
# 497_120515  ...                         7.654758
# 231_120425  ...                         7.703107
# 24_120411   ...                         7.690702
# ...         ...                              ...
# 74_120417   ...                         7.382157
# 360_120502  ...                         7.468472
# 72_120417   ...                         8.353156
# 470_120514  ...                         7.435881
# 386_120503  ...                         7.566526
#
#             ENSG00000171574_ENSG00000146859  ENSG00000185630_ENSG00000279302  \
# 427_120507                         9.683056                        12.234568
# 350_120501                         8.955410                        11.413670
# 497_120515                         8.459689                        12.259038
# 231_120425                         9.468503                        12.207537
# 24_120411                          8.937388                        11.494260
# ...                                     ...                              ...
# 74_120417                          8.463426                        12.006728
# 360_120502                         9.010273                        12.452053
# 72_120417                          8.354316                        11.900505
# 470_120514                         8.861829                        11.903550
# 386_120503                         9.034501                        12.239770
#
#             ENSG00000105722_ENSG00000064419  ENSG00000005513_ENSG00000213891  \
# 427_120507                         7.687873                        11.635471
# 350_120501                         7.719714                        11.597850
# 497_120515                         7.858682                        11.735506
# 231_120425                         7.732478                        11.851610
# 24_120411                          7.836052                        12.716869
# ...                                     ...                              ...
# 74_120417                          8.128431                        11.715865
# 360_120502                         7.558711                        11.662923
# 72_120417                          7.443180                        11.464351
# 470_120514                         7.457874                        11.532890
# 386_120503                         7.219823                        11.874992
#
#             ENSG00000151090_ENSG00000244754  ENSG00000168310_ENSG00000279561  \
# 427_120507                         5.990352                         6.105093
# 350_120501                         6.590043                         5.874321
# 497_120515                         5.229421                         6.055918
# 231_120425                         5.404873                         6.180373
# 24_120411                          6.509252                         6.166031
# ...                                     ...                              ...
# 74_120417                          6.298839                         5.941861
# 360_120502                         6.328104                         6.015099
# 72_120417                          6.796500                         6.038638
# 470_120514                         7.175874                         6.078769
# 386_120503                         6.366986                         6.021051
#
#             ENSG00000102349_ENSG00000158850  ENSG00000188290_ENSG00000183579  \
# 427_120507                         5.626414                         5.818312
# 350_120501                         5.978039                         5.786968
# 497_120515                         6.055321                         5.710395
# 231_120425                         6.092688                         5.784983
# 24_120411                          6.050775                         5.791155
# ...                                     ...                              ...
# 74_120417                          5.795591                         5.383570
# 360_120502                         5.939244                         5.938982
# 72_120417                          6.195236                         5.394404
# 470_120514                         5.635046                         5.895278
# 386_120503                         5.987022                         5.837669
#
#             Label
# 427_120507     AD
# 350_120501     AD
# 497_120515     AD
# 231_120425     AD
# 24_120411      AD
# ...           ...
# 74_120417     NCI
# 360_120502    NCI
# 72_120417     NCI
# 470_120514    NCI
# 386_120503    NCI
#
# [150 rows x 118490 columns]

# %%
import pandas as pd
import random
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_predict

# Assuming your DataFrame contains only numeric values
# If not, you might need to preprocess your data accordingly

accuracies = []

# Split the data into features (X) and target (y)
X = outlier_corrected_combined.drop(columns='Label')[l]
y = outlier_corrected_combined['Label']

# Initialize the model
model = LogisticRegression(class_weight={'AD': 1, 'NCI': 1})

# 5-Fold Cross-Validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Get cross-validation predictions
y_pred = cross_val_predict(model, X, y, cv=cv)

# Evaluate accuracy for each fold
accuracies = cross_val_score(model, X, y, cv=cv, scoring='accuracy')

# Print the average accuracy
print(f"Average Accuracy: {accuracies.mean():.2f} ± {accuracies.std():.2f}")

# Create boxplot of accuracies across folds
plt.figure(figsize=(10, 6))
sns.boxplot(data=accuracies)
plt.title('Cross-Validation Accuracy Distribution')
plt.ylabel('Accuracy')
plt.show()

# Confusion Matrix after cross-validation
conf_matrix = confusion_matrix(y, y_pred)

# Plot confusion matrix heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=y.unique(), yticklabels=y.unique())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Classification report
class_report = classification_report(y, y_pred)
print("\nClassification Report:")
print(class_report)
# Out:
# Average Accuracy: 0.96 ± 0.02
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Classification Report:
#               precision    recall  f1-score   support
#
#           AD       0.98      0.95      0.96        85
#          NCI       0.94      0.97      0.95        65
#
#     accuracy                           0.96       150
#    macro avg       0.96      0.96      0.96       150
# weighted avg       0.96      0.96      0.96       150

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import cross_val_predict, cross_val_score

# Assuming your DataFrame contains only numeric values
# If not, you might need to preprocess your data accordingly

# Split the data into features (X) and target (y)
X = outlier_corrected_combined.drop(columns='Label')[l]
y = outlier_corrected_combined['Label']

# Initialize the model
model = LogisticRegression(class_weight={'AD': 1, 'NCI': 1})

# 5-Fold Cross-Validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Store confusion matrices
conf_matrices = []

# Get cross-validation predictions and evaluate accuracy for each fold
accuracies = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
y_pred = cross_val_predict(model, X, y, cv=cv)

# Print the average accuracy
print(f"Average Accuracy: {accuracies.mean():.2f} ± {accuracies.std():.2f}")

# Create boxplot of accuracies across folds
plt.figure(figsize=(10, 6))
sns.boxplot(data=accuracies)
plt.title('Cross-Validation Accuracy Distribution')
plt.ylabel('Accuracy')
plt.show()

# Compute confusion matrix for each fold
for train_index, test_index in cv.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    # Fit the model and predict for this fold
    model.fit(X_train, y_train)
    y_fold_pred = model.predict(X_test)
    
    # Compute confusion matrix for this fold
    fold_conf_matrix = confusion_matrix(y_test, y_fold_pred)
    conf_matrices.append(fold_conf_matrix)

# Plot confusion matrix for each fold
fig, axes = plt.subplots(1, 5, figsize=(20, 4))  # 5 subplots for 5 folds
for i, (conf_matrix, ax) in enumerate(zip(conf_matrices, axes)):
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', ax=ax,
                xticklabels=y.unique(), yticklabels=y.unique(), cbar=False)
    ax.set_title(f'Fold {i+1}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
    
    # Add range (min/max) as a text annotation on the plot
    min_value = conf_matrix.min()
    max_value = conf_matrix.max()
   # ax.text(0.5, 0.5, f'Min: {min_value}\nMax: {max_value}', 
    #        ha='center', va='center', color='red', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

# Classification report
class_report = classification_report(y, y_pred)
print("\nClassification Report:")
print(class_report)
# Out:
# Average Accuracy: 0.96 ± 0.02
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Classification Report:
#               precision    recall  f1-score   support
#
#           AD       0.98      0.95      0.96        85
#          NCI       0.94      0.97      0.95        65
#
#     accuracy                           0.96       150
#    macro avg       0.96      0.96      0.96       150
# weighted avg       0.96      0.96      0.96       150

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from sklearn.model_selection import cross_val_predict, cross_val_score

# Assuming your DataFrame contains only numeric values
# If not, you might need to preprocess your data accordingly

# Split the data into features (X) and target (y)
X = outlier_corrected_combined.drop(columns='Label')[l]
y = outlier_corrected_combined['Label']

# Initialize the model
model = LogisticRegression(class_weight={'AD': 1, 'NCI': 1})

# 5-Fold Cross-Validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Store confusion matrices and F1 scores
conf_matrices = []
f1_scores = []

# Get cross-validation predictions and evaluate accuracy for each fold
accuracies = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
y_pred = cross_val_predict(model, X, y, cv=cv)

# Print the average accuracy
print(f"Average Accuracy: {accuracies.mean():.2f} ± {accuracies.std():.2f}")

# Create boxplot of accuracies across folds
plt.figure(figsize=(10, 6))
sns.boxplot(data=accuracies)
plt.title('Cross-Validation Accuracy Distribution')
plt.ylabel('Accuracy')
plt.show()

# Compute confusion matrix and F1 score for each fold
for train_index, test_index in cv.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    # Fit the model and predict for this fold
    model.fit(X_train, y_train)
    y_fold_pred = model.predict(X_test)
    
    # Compute confusion matrix for this fold
    fold_conf_matrix = confusion_matrix(y_test, y_fold_pred)
    conf_matrices.append(fold_conf_matrix)
    
    # Compute F1 score for this fold
    f1 = f1_score(y_test, y_fold_pred, average='weighted')  # weighted F1 score for imbalanced classes
    f1_scores.append(f1)

# Plot confusion matrix for each fold
fig, axes = plt.subplots(1, 5, figsize=(20, 4))  # 5 subplots for 5 folds
for i, (conf_matrix, ax) in enumerate(zip(conf_matrices, axes)):
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', ax=ax,
                xticklabels=y.unique(), yticklabels=y.unique(), cbar=False)
    ax.set_title(f'Fold {i+1}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')

plt.tight_layout()
plt.show()

# Print F1 scores for each fold
print("\nF1 Scores for each fold:")
for i, f1 in enumerate(f1_scores, 1):
    print(f"Fold {i}: F1 Score = {f1:.2f}")

# Classification report
class_report = classification_report(y, y_pred)
print("\nClassification Report:")
print(class_report)
# Out:
# Average Accuracy: 0.96 ± 0.02
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# F1 Scores for each fold:
# Fold 1: F1 Score = 0.93
# Fold 2: F1 Score = 0.93
# Fold 3: F1 Score = 0.97
# Fold 4: F1 Score = 1.00
# Fold 5: F1 Score = 0.97
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           AD       0.98      0.95      0.96        85
#          NCI       0.94      0.97      0.95        65
#
#     accuracy                           0.96       150
#    macro avg       0.96      0.96      0.96       150
# weighted avg       0.96      0.96      0.96       150

# %%
from sklearn.manifold import TSNE
from tqdm import tqdm
import pandas as pd
import random
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
import plotly.express as px
from sklearn.neighbors import KNeighborsClassifier
Y = outlier_corrected_combined.loc[:,'Label']
#Y = Y.replace({'NCI':1,'AD':0})
for i in tqdm(range(15999,16000,1)):
    #important_genes = list(df.iloc[0:i,].Genes)
    X_ = outlier_corrected_combined.drop(columns = ['Label'])[l]
    
    scaler = StandardScaler()
    pca = PCA(n_components=2)
    
    X_scaled = scaler.fit_transform(X_)
    tsne = TSNE(n_components=2, random_state = 43)

    
    X_low_d =tsne.fit_transform(X_scaled)


 
    
    
    print(X_low_d.shape)
    print(X_.shape)
    df = pd.DataFrame({'X': X_tsne[:, 0], 'Y': X_tsne[:, 1], 'Label': Y})
    df['point_size'] = 5
    #plt.scatter(X_tsne[:,0], X_tsne[:,1], c= Y, cmap = 'viridis')
    
    fig = px.scatter(df, x='X', y='Y', color='Label', title='t-SNE Plot on 48 key genes of GRNs ',size ='point_size',size_max=10,
                 labels={'X': 'X-axis', 'Y': 'Y-axis', 'Label': 'Disease State'},
                 template='plotly', symbol='Label', symbol_sequence=['circle', 'triangle-up'])


    fig.update_layout(
    
        title_x=0.5,  # Set the x-position of the title to center
        title_y=0.95  # Set the y-position of the title to center
    )
    fig.update_layout(legend=dict(font=dict(size=18)), yaxis = dict(tickfont = dict(size=15)), xaxis = dict(tickfont = dict(size=15)))
    fig.update_layout(xaxis=dict(title=(dict(font=dict(size=20)))),yaxis=dict(title=(dict(font=dict(size=20)))))
    fig.update_layout(width = 1100, height = 550)
# Convert Plotly figure to Matplotlib figure
    fig.update_layout(title=(dict(font=dict(size=30))))
    fig.show()
    fig.write_html("plotly_figure_key_genes.html")

   # plt.title(str(accuracy) + '_'+str(recall_score(y,y_pred, pos_label = 0))+ '_'+ str(recall_score(y,y_pred, pos_label = 1)))
    plt.show()
# Out:
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
# (150, 2)
# (150, 22)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  3.95it/s]

# %%
from sklearn.manifold import TSNE
from tqdm import tqdm
import pandas as pd
import random
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
import plotly.express as px
from sklearn.neighbors import KNeighborsClassifier
Y = outlier_corrected_combined.loc[:,'Label']
#Y = Y.replace({'NCI':1,'AD':0})
for i in tqdm(range(15999,16000,1)):
    #important_genes = list(df.iloc[0:i,].Genes)
    X_ = outlier_corrected_combined.drop(columns = ['Label'])
    
    scaler = StandardScaler()
    pca = PCA(n_components=2)
    tsne = TSNE(n_components=2, random_state = 43)
    
    X_scaled = scaler.fit_transform(X_)
    
    X_low_d = pca.fit_transform(X_scaled)
    X_low_d  = tsne.fit_transform(X_scaled)

    
    print(X_low_d.shape)
    print(X_.shape)
    df = pd.DataFrame({'X': X_low_d[:, 0], 'Y': X_low_d[:, 1], 'Label': Y})
    df['point_size'] = 5
    #plt.scatter(X_tsne[:,0], X_tsne[:,1], c= Y, cmap = 'viridis')
    
    fig = px.scatter(df_pca, x='X', y='Y', color='Label', title='PCA Plot on 44 key genes of GRNs ',size ='point_size',size_max=10,
                 labels={'X': 'X-axis', 'Y': 'Y-axis', 'Label': 'Disease State'},
                 template='plotly', symbol='Label', symbol_sequence=['circle', 'triangle-up'])


    fig.update_layout(
    
        title_x=0.5,  # Set the x-position of the title to center
        title_y=0.95  # Set the y-position of the title to center
    )
    fig.update_layout(legend=dict(font=dict(size=18)), yaxis = dict(tickfont = dict(size=15)), xaxis = dict(tickfont = dict(size=15)))
    fig.update_layout(xaxis=dict(title=(dict(font=dict(size=20)))),yaxis=dict(title=(dict(font=dict(size=20)))))
    fig.update_layout(width = 1100, height = 550)
# Convert Plotly figure to Matplotlib figure
    fig.update_layout(title=(dict(font=dict(size=30))))
    fig.show()
    fig.write_html("plotly_figure_key_genes.html")

   # plt.title(str(accuracy) + '_'+str(recall_score(y,y_pred, pos_label = 0))+ '_'+ str(recall_score(y,y_pred, pos_label = 1)))
    plt.show()
# Out:
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
# (150, 2)
# (150, 118489)
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.51s/it]

# %%
x = outlier_corrected_combined.columns[0:-1]

# %%
# Out:
# ['ENSG00000164736_ENSG00000259295',
#  'ENSG00000136997_ENSG00000172428',
#  'ENSG00000168826_ENSG00000205358',
#  'ENSG00000179627_ENSG00000255176',
#  'ENSG00000171291_ENSG00000104859',
#  'ENSG00000175832_ENSG00000164190',
#  'ENSG00000184517_ENSG00000169499',
#  'ENSG00000128573_ENSG00000143157',
#  'ENSG00000185022_ENSG00000143815',
#  'ENSG00000188227_ENSG00000219481',
#  'ENSG00000177045_ENSG00000102904',
#  'ENSG00000121068_ENSG00000169118',
#  'ENSG00000082175_ENSG00000130037',
#  'ENSG00000196378_ENSG00000274341',
#  'ENSG00000198556_ENSG00000187210',
#  'ENSG00000173757_ENSG00000271646',
#  'ENSG00000198482_ENSG00000276728',
#  'ENSG00000147421_ENSG00000167613',
#  'ENSG00000080298_ENSG00000134775',
#  'ENSG00000154957_ENSG00000178538',
#  'ENSG00000068323_ENSG00000078246',
#  'ENSG00000125285_ENSG00000224078',
#  'ENSG00000112837_ENSG00000240219',
#  'ENSG00000175832_ENSG00000164332',
#  'ENSG00000178860_ENSG00000049283',
#  'ENSG00000088876_ENSG00000180370',
#  'ENSG00000113580_ENSG00000153902',
#  'ENSG00000162772_ENSG00000198901',
#  'ENSG00000009950_ENSG00000172775',
#  'ENSG00000188227_ENSG00000168792',
#  'ENSG00000111269_ENSG00000102543',
#  'ENSG00000175322_ENSG00000158290',
#  'ENSG00000126368_ENSG00000167716',
#  'ENSG00000184828_ENSG00000133704',
#  'ENSG00000111206_ENSG00000181192',
#  'ENSG00000125347_ENSG00000245571',
#  'ENSG00000105722_ENSG00000196605',
#  'ENSG00000072310_ENSG00000127334',
#  'ENSG00000147124_ENSG00000113594',
#  'ENSG00000197013_ENSG00000162654',
#  'ENSG00000198298_ENSG00000277778',
#  'ENSG00000170653_ENSG00000189221',
#  'ENSG00000176293_ENSG00000259953',
#  'ENSG00000170485_ENSG00000218227']

# %%
import pandas as pd
import random
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler


# Assuming your DataFrame contains only numeric values
# If not, you might need to preprocess your data accordingly

accuracies_44 = []

# Split the data into training and testing sets

for i in tqdm(range(1000)):
    random_44 = random.sample(list(x) , 44)

    X_train, X_test, y_train, y_test = train_test_split(outlier_corrected_combined.drop(columns='Label')[random_44], outlier_corrected_combined['Label'], test_size=0.2, random_state = 42)

    #y_train = random.sample(list(y_train), len(list(y_train)))
    #y_test = random.sample(list(y_test), len(list(y_test)))
    # Initialize and train the logistic regression model
    #scaler = StandardScaler()
    #X_train_scaled = scaler.fit_transform(X_train)
    #X_test_scaled = scaler.transform(X_test)
    model = LogisticRegression(class_weight={'AD':1,'NCI':1})
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model performance
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)
    accuracies_44.append(accuracy)
    print(accuracy)
# Out:
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   0%|▏                                         | 3/1000 [00:00<00:46, 21.45it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6333333333333333
# 0.6666666666666666
# 0.6666666666666666
# 0.6333333333333333
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▎                                         | 6/1000 [00:00<00:44, 22.19it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▍                                         | 9/1000 [00:00<00:44, 22.40it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.5333333333333333
# 0.7
# 0.43333333333333335
# 0.7333333333333333
# 0.5333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▍                                        | 12/1000 [00:00<00:43, 22.56it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▌                                        | 15/1000 [00:00<00:43, 22.61it/s]
# 0.6666666666666666
# 0.7
# 0.6333333333333333
# 0.6666666666666666
# 0.5666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▋                                        | 18/1000 [00:00<00:43, 22.70it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6
# 0.5
# 0.6
# 0.6
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▊                                        | 21/1000 [00:00<00:42, 22.78it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▉                                        | 24/1000 [00:01<00:42, 22.79it/s]
# 0.6
# 0.6666666666666666
# 0.43333333333333335
# 0.6
# 0.5333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█                                        | 27/1000 [00:01<00:42, 22.78it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▏                                       | 30/1000 [00:01<00:42, 22.76it/s]
# 0.7
# 0.6333333333333333
# 0.4666666666666667
# 0.7666666666666667
# 0.5
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▎                                       | 33/1000 [00:01<00:42, 22.80it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6333333333333333
# 0.6666666666666666
# 0.6
# 0.5333333333333333
# 0.6
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▍                                       | 36/1000 [00:01<00:42, 22.82it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▌                                       | 39/1000 [00:01<00:42, 22.84it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.5666666666666667
# 0.6666666666666666
# 0.5666666666666667
# 0.6
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▋                                       | 42/1000 [00:01<00:41, 22.87it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▊                                       | 45/1000 [00:01<00:41, 22.78it/s]
# 0.7
# 0.6333333333333333
# 0.5666666666666667
# 0.8
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|█▉                                       | 48/1000 [00:02<00:41, 22.80it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6333333333333333
# 0.7
# 0.6333333333333333
# 0.7
# 0.5666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██                                       | 51/1000 [00:02<00:42, 22.45it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██▏                                      | 54/1000 [00:02<00:41, 22.55it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.5
# 0.5
# 0.7
# 0.6
# 0.7666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▎                                      | 57/1000 [00:02<00:41, 22.59it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▍                                      | 60/1000 [00:02<00:41, 22.63it/s]
# 0.7333333333333333
# 0.5333333333333333
# 0.5
# 0.5666666666666667
# 0.5
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▌                                      | 63/1000 [00:02<00:41, 22.66it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6666666666666666
# 0.6666666666666666
# 0.5666666666666667
# 0.6
# 0.5666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▋                                      | 66/1000 [00:02<00:41, 22.67it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▊                                      | 69/1000 [00:03<00:40, 22.74it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6
# 0.7333333333333333
# 0.5333333333333333
# 0.6666666666666666
# 0.5333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▉                                      | 72/1000 [00:03<00:40, 22.78it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███                                      | 75/1000 [00:03<00:40, 22.84it/s]
# 0.5666666666666667
# 0.6
# 0.6
# 0.6333333333333333
# 0.6
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▏                                     | 78/1000 [00:03<00:40, 22.80it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.5666666666666667
# 0.6333333333333333
# 0.7666666666666667
# 0.6
# 0.5666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▎                                     | 81/1000 [00:03<00:40, 22.74it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▍                                     | 84/1000 [00:03<00:40, 22.72it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6
# 0.5333333333333333
# 0.7
# 0.6666666666666666
# 0.5333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   9%|███▌                                     | 87/1000 [00:03<00:40, 22.74it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  97%|██████████████████████████████████████▉ | 972/1000 [00:42<00:01, 22.69it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████ | 975/1000 [00:42<00:01, 22.67it/s]
# 0.6
# 0.6666666666666666
# 0.7
# 0.7333333333333333
# 0.6
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████ | 978/1000 [00:43<00:00, 22.54it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6666666666666666
# 0.7666666666666667
# 0.7
# 0.7
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▏| 981/1000 [00:43<00:00, 22.58it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▎| 984/1000 [00:43<00:00, 22.61it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6
# 0.6
# 0.7666666666666667
# 0.6
# 0.6
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▍| 987/1000 [00:43<00:00, 22.67it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▌| 990/1000 [00:43<00:00, 22.57it/s]
# 0.7333333333333333
# 0.7
# 0.7
# 0.6666666666666666
# 0.6
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▋| 993/1000 [00:43<00:00, 22.57it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7
# 0.7333333333333333
# 0.6
# 0.6333333333333333
# 0.5666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████▊| 996/1000 [00:43<00:00, 22.63it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████▉| 999/1000 [00:43<00:00, 22.69it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████| 1000/1000 [00:43<00:00, 22.73it/s]
# 0.6333333333333333
# 0.6333333333333333
# 0.5666666666666667
# 0.9
# 0.6333333333333333

# %%
accuracies
# Out:
# [0.6333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.7,
#  0.43333333333333335,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6,
#  0.5,
#  0.6,
#  0.6,
#  0.7,
#  0.6,
#  0.6666666666666666,
#  0.43333333333333335,
#  0.6,
#  0.5333333333333333,
#  0.7,
#  0.6333333333333333,
#  0.4666666666666667,
#  0.7666666666666667,
#  0.5,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.5333333333333333,
#  0.6,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6,
#  0.7333333333333333,
#  0.7,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.8,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.7,
#  0.6333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.5,
#  0.5,
#  0.7,
#  0.6,
#  0.7666666666666667,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.5,
#  0.5666666666666667,
#  0.5,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6,
#  0.5666666666666667,
#  0.6,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.6,
#  0.6,
#  0.6333333333333333,
#  0.6,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.6,
#  0.5666666666666667,
#  0.6,
#  0.5333333333333333,
#  0.7,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.7,
#  0.6,
#  0.5666666666666667,
#  0.7333333333333333,
#  0.7,
#  0.6,
#  0.43333333333333335,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.5,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.7,
#  0.5,
#  0.7,
#  0.5,
#  0.7,
#  0.6333333333333333,
#  0.4666666666666667,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.7,
#  0.7,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.7,
#  0.5666666666666667,
#  0.4666666666666667,
#  0.6333333333333333,
#  0.4666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.6,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.6,
#  0.5333333333333333,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.6,
#  0.5,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.7666666666666667,
#  0.5,
#  0.6666666666666666,
#  0.7,
#  0.6333333333333333,
#  0.6,
#  0.5666666666666667,
#  0.7,
#  0.7,
#  0.6,
#  0.4666666666666667,
#  0.7666666666666667,
#  0.7666666666666667,
#  0.5333333333333333,
#  0.6,
#  0.5666666666666667,
#  0.43333333333333335,
#  0.7666666666666667,
#  0.7333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.43333333333333335,
#  0.6666666666666666,
#  0.6,
#  0.6666666666666666,
#  0.43333333333333335,
#  0.5666666666666667,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.7,
#  0.7333333333333333,
#  0.5666666666666667,
#  0.43333333333333335,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.6333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.6,
#  0.5,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.7,
#  0.7,
#  0.7,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.7,
#  0.6333333333333333,
#  0.6,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.5,
#  0.6333333333333333,
#  0.5,
#  0.4666666666666667,
#  0.7,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7,
#  0.6666666666666666,
#  0.5,
#  0.7,
#  0.7,
#  0.6,
#  0.5,
#  0.7333333333333333,
#  0.7,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.7333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.6,
#  0.6,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.7333333333333333,
#  0.6,
#  0.5666666666666667,
#  0.5,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.7,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.5,
#  0.6333333333333333,
#  0.8,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6,
#  0.5666666666666667,
#  0.6,
#  0.6,
#  0.6,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.5,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.8,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5,
#  0.4666666666666667,
#  0.6,
#  0.5666666666666667,
#  0.7,
#  0.6666666666666666,
#  0.8333333333333334,
#  0.5,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.7,
#  0.6666666666666666,
#  0.4666666666666667,
#  0.6,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.5,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6,
#  0.5333333333333333,
#  0.7333333333333333,
#  0.6,
#  0.6,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.7,
#  0.4666666666666667,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.4,
#  0.7,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.6,
#  0.6333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.6,
#  0.7666666666666667,
#  0.7,
#  0.6333333333333333,
#  0.5,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.5,
#  0.8,
#  0.6,
#  0.6,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.5,
#  0.6,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.8,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.5,
#  0.5,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.4666666666666667,
#  0.5666666666666667,
#  0.7,
#  0.5,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.7,
#  0.6,
#  0.7,
#  0.5666666666666667,
#  0.8,
#  0.6666666666666666,
#  0.5,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6,
#  0.5,
#  0.4666666666666667,
#  0.6666666666666666,
#  0.7,
#  0.4666666666666667,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.7,
#  0.7,
#  0.6,
#  0.6666666666666666,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.6,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.6,
#  0.6666666666666666,
#  0.5,
#  0.4666666666666667,
#  0.7,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6,
#  0.4666666666666667,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6,
#  0.7333333333333333,
#  0.5666666666666667,
#  0.7333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.8,
#  0.6,
#  0.4666666666666667,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.5,
#  0.7,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.7,
#  0.7333333333333333,
#  0.5666666666666667,
#  0.7,
#  0.7,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.5,
#  0.7,
#  0.6,
#  0.8,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.8,
#  0.6,
#  0.6,
#  0.6,
#  0.8333333333333334,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.43333333333333335,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.6,
#  0.5,
#  0.7,
#  0.7666666666666667,
#  0.7,
#  0.6,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.6,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6,
#  0.6,
#  0.5,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.7,
#  0.5,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.6,
#  0.7,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.8,
#  0.5333333333333333,
#  0.7666666666666667,
#  0.6,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.7,
#  0.6,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.6,
#  0.5,
#  0.5,
#  0.8,
#  0.6666666666666666,
#  0.5,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.5,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.6,
#  0.5,
#  0.7,
#  0.7,
#  0.5333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.5333333333333333,
#  0.7,
#  0.36666666666666664,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.43333333333333335,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.6,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.4666666666666667,
#  0.8,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.7,
#  0.5,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.5,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.6,
#  0.6666666666666666,
#  0.6,
#  0.6,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.8,
#  0.6333333333333333,
#  0.6,
#  0.6333333333333333,
#  0.6,
#  0.7,
#  0.7,
#  0.6666666666666666,
#  0.7,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.6,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.7,
#  0.7,
#  0.5333333333333333,
#  0.6,
#  0.5,
#  0.4666666666666667,
#  0.43333333333333335,
#  0.8666666666666667,
#  0.7333333333333333,
#  0.6,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.4666666666666667,
#  0.5,
#  0.7,
#  0.6,
#  0.5,
#  0.7,
#  0.6,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.5,
#  0.5666666666666667,
#  0.7,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.5,
#  0.4666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.6,
#  0.6666666666666666,
#  0.4666666666666667,
#  0.5666666666666667,
#  0.6,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.5,
#  0.6666666666666666,
#  0.6,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5,
#  0.6333333333333333,
#  0.7,
#  0.7333333333333333,
#  0.6,
#  0.6,
#  0.6,
#  0.6333333333333333,
#  0.4666666666666667,
#  0.7,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.8,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.8,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.7,
#  0.43333333333333335,
#  0.5333333333333333,
#  0.6,
#  0.7,
#  0.5,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.8,
#  0.6333333333333333,
#  0.4,
#  0.6,
#  0.6333333333333333,
#  0.7,
#  0.6,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.6,
#  0.7,
#  0.6,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.5,
#  0.5666666666666667,
#  0.5,
#  0.7,
#  0.6,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.7,
#  0.6,
#  0.8,
#  0.6,
#  0.6666666666666666,
#  0.6,
#  0.5,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.8,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.5,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.8,
#  0.5333333333333333,
#  0.6,
#  0.6,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.7333333333333333,
#  0.6,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.43333333333333335,
#  0.5333333333333333,
#  0.7333333333333333,
#  0.6,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.7,
#  0.5,
#  0.6,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.6,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.5,
#  0.7666666666666667,
#  0.7,
#  0.6,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.7,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.6,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.8,
#  0.7333333333333333,
#  0.5,
#  0.4666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.4666666666666667,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.5666666666666667,
#  0.7,
#  0.6,
#  0.9,
#  0.43333333333333335,
#  0.5,
#  0.6,
#  0.6,
#  0.7333333333333333,
#  0.5,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6,
#  0.5666666666666667,
#  0.6,
#  0.6,
#  0.5,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.7,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.5,
#  0.7666666666666667,
#  0.7,
#  0.6,
#  0.7,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.5,
#  0.6,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.8,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.7333333333333333,
#  0.5666666666666667,
#  0.7,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.7,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6,
#  0.5666666666666667,
#  0.6,
#  0.7,
#  0.7,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.5333333333333333,
#  0.6,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6,
#  0.8333333333333334,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.7,
#  0.6333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.5,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.7,
#  0.6,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.7,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.7333333333333333,
#  0.5,
#  0.6,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.4666666666666667,
#  0.6,
#  0.6,
#  0.6666666666666666,
#  0.7,
#  0.7333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.7,
#  0.7,
#  0.6333333333333333,
#  0.6,
#  0.6,
#  0.7666666666666667,
#  0.6,
#  0.6,
#  0.7333333333333333,
#  0.7,
#  0.7,
#  0.6666666666666666,
#  0.6,
#  0.7,
#  0.7333333333333333,
#  0.6,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.9,
#  0.6333333333333333]

# %%
accuracies_100 = []

# Split the data into training and testing sets

for i in tqdm(range(1000)):
    random_44 = random.sample(list(x) , 100)

    X_train, X_test, y_train, y_test = train_test_split(outlier_corrected_combined.drop(columns='Label')[random_44], outlier_corrected_combined['Label'], test_size=0.2, random_state = 42)

    #y_train = random.sample(list(y_train), len(list(y_train)))
    #y_test = random.sample(list(y_test), len(list(y_test)))
    # Initialize and train the logistic regression model
    #scaler = StandardScaler()
    #X_train_scaled = scaler.fit_transform(X_train)
    #X_test_scaled = scaler.transform(X_test)
    model = LogisticRegression(class_weight={'AD':1,'NCI':1})
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model performance
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)
    accuracies_100.append(accuracy)
    print(accuracy)
# Out:
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   0%|                                          | 2/1000 [00:00<01:00, 16.58it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   0%|▏                                         | 4/1000 [00:00<01:02, 16.05it/s]
# 0.7
# 0.7333333333333333
# 0.5666666666666667
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▎                                         | 6/1000 [00:00<01:04, 15.43it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▎                                         | 8/1000 [00:00<01:03, 15.64it/s]
# 0.7
# 0.7
# 0.6666666666666666
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▍                                        | 10/1000 [00:00<01:02, 15.79it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▍                                        | 12/1000 [00:00<01:02, 15.84it/s]
# 0.7
# 0.6
# 0.5333333333333333
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▌                                        | 14/1000 [00:00<01:02, 15.89it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▋                                        | 16/1000 [00:01<01:01, 15.91it/s]
# 0.6333333333333333
# 0.6666666666666666
# 0.6333333333333333
# 0.5333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▋                                        | 18/1000 [00:01<01:01, 15.91it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▊                                        | 20/1000 [00:01<01:01, 15.94it/s]
# 0.5666666666666667
# 0.6333333333333333
# 0.6333333333333333
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▉                                        | 22/1000 [00:01<01:01, 15.94it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▉                                        | 24/1000 [00:01<01:01, 15.96it/s]
# 0.6666666666666666
# 0.6333333333333333
# 0.8
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█                                        | 26/1000 [00:01<01:00, 15.98it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▏                                       | 28/1000 [00:01<01:00, 15.95it/s]
# 0.7666666666666667
# 0.7
# 0.6
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▏                                       | 30/1000 [00:01<01:00, 15.97it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▎                                       | 32/1000 [00:02<01:00, 15.97it/s]
# 0.7
# 0.6666666666666666
# 0.6666666666666666
# 0.5666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▍                                       | 34/1000 [00:02<01:00, 15.98it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▍                                       | 36/1000 [00:02<01:00, 15.97it/s]
# 0.6333333333333333
# 0.5666666666666667
# 0.4666666666666667
# 0.6
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▌                                       | 38/1000 [00:02<01:00, 15.96it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▋                                       | 40/1000 [00:02<01:00, 15.96it/s]
# 0.6666666666666666
# 0.6333333333333333
# 0.7333333333333333
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▋                                       | 42/1000 [00:02<01:00, 15.96it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▊                                       | 44/1000 [00:02<01:00, 15.76it/s]
# 0.7666666666666667
# 0.7
# 0.7666666666666667
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|█▉                                       | 46/1000 [00:02<01:00, 15.83it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|█▉                                       | 48/1000 [00:03<00:59, 15.90it/s]
# 0.7666666666666667
# 0.7666666666666667
# 0.6
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██                                       | 50/1000 [00:03<00:59, 15.92it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██▏                                      | 52/1000 [00:03<00:59, 15.90it/s]
# 0.7
# 0.5
# 0.5
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██▏                                      | 54/1000 [00:03<00:59, 15.90it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▎                                      | 56/1000 [00:03<00:59, 15.85it/s]
# 0.7
# 0.6333333333333333
# 0.6666666666666666
# 0.7666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▍                                      | 58/1000 [00:03<00:59, 15.89it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▍                                      | 60/1000 [00:03<00:59, 15.90it/s]
# 0.6333333333333333
# 0.6
# 0.7
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▌                                      | 62/1000 [00:03<00:58, 15.90it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▌                                      | 64/1000 [00:04<00:58, 15.91it/s]
# 0.6666666666666666
# 0.8
# 0.8333333333333334
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▋                                      | 66/1000 [00:04<00:58, 15.90it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▊                                      | 68/1000 [00:04<00:58, 15.90it/s]
# 0.6666666666666666
# 0.7
# 0.6333333333333333
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▊                                      | 70/1000 [00:04<00:58, 15.98it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▉                                      | 72/1000 [00:04<00:57, 16.03it/s]
# 0.6
# 0.5666666666666667
# 0.7
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|███                                      | 74/1000 [00:04<00:57, 16.03it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███                                      | 76/1000 [00:04<00:57, 16.00it/s]
# 0.6666666666666666
# 0.8
# 0.6
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▏                                     | 78/1000 [00:04<00:57, 16.00it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▎                                     | 80/1000 [00:05<00:57, 16.00it/s]
# 0.6333333333333333
# 0.6666666666666666
# 0.6666666666666666
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▎                                     | 82/1000 [00:05<00:57, 15.98it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▍                                     | 84/1000 [00:05<00:57, 15.97it/s]
# 0.6333333333333333
# 0.7333333333333333
# 0.6
# 0.6
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   9%|███▌                                     | 86/1000 [00:05<00:57, 15.94it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  97%|██████████████████████████████████████▉ | 972/1000 [01:01<00:01, 15.99it/s]
# 0.7333333333333333
# 0.7333333333333333
# 0.6333333333333333
# 0.5666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  97%|██████████████████████████████████████▉ | 974/1000 [01:01<00:01, 15.97it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████ | 976/1000 [01:01<00:01, 15.96it/s]
# 0.6
# 0.9
# 0.5666666666666667
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████ | 978/1000 [01:01<00:01, 15.97it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▏| 980/1000 [01:01<00:01, 15.95it/s]
# 0.6
# 0.6666666666666666
# 0.7
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▎| 982/1000 [01:01<00:01, 15.95it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▎| 984/1000 [01:01<00:01, 15.96it/s]
# 0.8
# 0.7333333333333333
# 0.7
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▍| 986/1000 [01:01<00:00, 15.93it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▌| 988/1000 [01:02<00:00, 15.95it/s]
# 0.6666666666666666
# 0.7
# 0.6666666666666666
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▌| 990/1000 [01:02<00:00, 15.97it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▋| 992/1000 [01:02<00:00, 15.95it/s]
# 0.6666666666666666
# 0.7
# 0.6
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▊| 994/1000 [01:02<00:00, 15.97it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████▊| 996/1000 [01:02<00:00, 15.97it/s]
# 0.6333333333333333
# 0.7333333333333333
# 0.6333333333333333
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████▉| 998/1000 [01:02<00:00, 15.95it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████| 1000/1000 [01:02<00:00, 15.93it/s]
# 0.6333333333333333
# 0.8
# 0.6333333333333333
# 0.8

# %%
accuracies_100
# Out:
# [0.7,
#  0.7333333333333333,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.7,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7,
#  0.6,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.8,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.7,
#  0.6,
#  0.6333333333333333,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.4666666666666667,
#  0.6,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.7666666666666667,
#  0.7,
#  0.7666666666666667,
#  0.7,
#  0.7666666666666667,
#  0.7666666666666667,
#  0.6,
#  0.6666666666666666,
#  0.7,
#  0.5,
#  0.5,
#  0.6333333333333333,
#  0.7,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.8,
#  0.8333333333333334,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.5666666666666667,
#  0.7,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.8,
#  0.6,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.6,
#  0.6,
#  0.6333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.7333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.7,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.6,
#  0.7,
#  0.6,
#  0.5666666666666667,
#  0.7666666666666667,
#  0.7666666666666667,
#  0.5666666666666667,
#  0.6,
#  0.7333333333333333,
#  0.7666666666666667,
#  0.7666666666666667,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.8,
#  0.5666666666666667,
#  0.5,
#  0.7666666666666667,
#  0.7333333333333333,
#  0.8,
#  0.8,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.6,
#  0.6,
#  0.8,
#  0.7,
#  0.7666666666666667,
#  0.5333333333333333,
#  0.6,
#  0.7666666666666667,
#  0.7,
#  0.6666666666666666,
#  0.7,
#  0.7,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.7,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.8,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.7666666666666667,
#  0.7,
#  0.7,
#  0.7,
#  0.6666666666666666,
#  0.7,
#  0.7333333333333333,
#  0.5,
#  0.7,
#  0.7,
#  0.6666666666666666,
#  0.6,
#  0.7,
#  0.5,
#  0.6,
#  0.7,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.7,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.7,
#  0.5,
#  0.6,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.6,
#  0.8333333333333334,
#  0.7666666666666667,
#  0.7,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.7,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.7666666666666667,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.7,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.6,
#  0.8,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.5666666666666667,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.8,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7,
#  0.5,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.8333333333333334,
#  0.8666666666666667,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.6,
#  0.7,
#  0.7666666666666667,
#  0.7333333333333333,
#  0.6,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.6,
#  0.6333333333333333,
#  0.6,
#  0.8333333333333334,
#  0.7333333333333333,
#  0.5666666666666667,
#  0.5,
#  0.7,
#  0.7,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.8333333333333334,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.6666666666666666,
#  0.7,
#  0.6666666666666666,
#  0.6,
#  0.5333333333333333,
#  0.7666666666666667,
#  0.6,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.7,
#  0.7,
#  0.6666666666666666,
#  0.6,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.7333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.7,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.8,
#  0.6333333333333333,
#  0.4666666666666667,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.8,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.7,
#  0.7,
#  0.8,
#  0.7666666666666667,
#  0.5666666666666667,
#  0.5,
#  0.8,
#  0.4666666666666667,
#  0.6,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.7666666666666667,
#  0.5666666666666667,
#  0.7333333333333333,
#  0.7,
#  0.7666666666666667,
#  0.7,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.6,
#  0.6333333333333333,
#  0.6,
#  0.4666666666666667,
#  0.7333333333333333,
#  0.6,
#  0.5333333333333333,
#  0.7,
#  0.7,
#  0.6333333333333333,
#  0.8,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.7,
#  0.6,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.5666666666666667,
#  0.7,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.7,
#  0.6666666666666666,
#  0.7,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.7,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.7666666666666667,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.7666666666666667,
#  0.4666666666666667,
#  0.6333333333333333,
#  0.8,
#  0.6666666666666666,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.7333333333333333,
#  0.8333333333333334,
#  0.5666666666666667,
#  0.5,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.7333333333333333,
#  0.7666666666666667,
#  0.7,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.6,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.8333333333333334,
#  0.6,
#  0.5666666666666667,
#  0.7,
#  0.6666666666666666,
#  0.8,
#  0.7666666666666667,
#  0.5666666666666667,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.5,
#  0.7,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.7,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.7666666666666667,
#  0.6,
#  0.6,
#  0.7,
#  0.7,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.6333333333333333,
#  0.7,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6,
#  0.5666666666666667,
#  0.7,
#  0.6,
#  0.6,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.7,
#  0.7,
#  0.5666666666666667,
#  0.7,
#  0.6,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6,
#  0.6,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.8,
#  0.7,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.6,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.5,
#  0.6,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.6333333333333333,
#  0.6,
#  0.6,
#  0.7,
#  0.6333333333333333,
#  0.6,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.7333333333333333,
#  0.7,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.5,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.5666666666666667,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.6,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.6,
#  0.6666666666666666,
#  0.5,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.6,
#  0.8333333333333334,
#  0.7,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.8333333333333334,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.5,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6,
#  0.8,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.7,
#  0.7,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.7,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.6,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.5666666666666667,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.7333333333333333,
#  0.6,
#  0.5333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.5,
#  0.7,
#  0.7666666666666667,
#  0.7,
#  0.7,
#  0.8,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.6333333333333333,
#  0.7666666666666667,
#  0.7,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.8,
#  0.7333333333333333,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.8,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.5,
#  0.6,
#  0.6,
#  0.7333333333333333,
#  0.6,
#  0.7333333333333333,
#  0.7,
#  0.6,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.6333333333333333,
#  0.7,
#  0.7,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.5,
#  0.6,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.7333333333333333,
#  0.7666666666666667,
#  0.6,
#  0.6,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.7,
#  0.7333333333333333,
#  0.6,
#  0.7,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.7333333333333333,
#  0.6,
#  0.6,
#  0.5333333333333333,
#  0.7666666666666667,
#  0.7666666666666667,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.5333333333333333,
#  0.6,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.6,
#  0.7333333333333333,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.7,
#  0.6,
#  0.8,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.7,
#  0.7333333333333333,
#  0.6,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.8,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.6,
#  0.8333333333333334,
#  0.6,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6,
#  0.7666666666666667,
#  0.5333333333333333,
#  0.6,
#  0.7666666666666667,
#  0.7,
#  0.6,
#  0.6,
#  0.6333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.7666666666666667,
#  0.7666666666666667,
#  0.6333333333333333,
#  0.7,
#  0.7666666666666667,
#  0.7666666666666667,
#  0.7,
#  0.7,
#  0.6,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.6,
#  0.6,
#  0.7333333333333333,
#  0.7,
#  0.7333333333333333,
#  0.7,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.8,
#  0.6666666666666666,
#  0.8,
#  0.6,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.7666666666666667,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.8,
#  0.6,
#  0.6666666666666666,
#  0.6,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.6,
#  0.7333333333333333,
#  0.6,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.6,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6333333333333333,
#  0.8333333333333334,
#  0.7666666666666667,
#  0.7333333333333333,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.7,
#  0.5,
#  0.7,
#  0.6,
#  0.7,
#  0.6,
#  0.7,
#  0.8,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.7,
#  0.8,
#  0.6666666666666666,
#  0.8666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.7,
#  0.7333333333333333,
#  0.5,
#  0.6,
#  0.8,
#  0.7,
#  0.6,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.7,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.7,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.5666666666666667,
#  0.6,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6,
#  0.5,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6,
#  0.6,
#  0.5666666666666667,
#  0.7,
#  0.6,
#  0.6666666666666666,
#  0.6,
#  0.7,
#  0.7333333333333333,
#  0.7666666666666667,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7,
#  0.6666666666666666,
#  0.5333333333333333,
#  0.7666666666666667,
#  0.7,
#  0.7666666666666667,
#  0.7,
#  0.8666666666666667,
#  0.6333333333333333,
#  0.6,
#  0.6,
#  0.7666666666666667,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.7,
#  0.6666666666666666,
#  0.6,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.7,
#  0.7,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7,
#  0.6,
#  0.6666666666666666,
#  0.8,
#  0.6666666666666666,
#  0.5666666666666667,
#  0.6,
#  0.4666666666666667,
#  0.6,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.7,
#  0.7333333333333333,
#  0.7,
#  0.7666666666666667,
#  0.7,
#  0.5666666666666667,
#  0.6333333333333333,
#  0.6,
#  0.7,
#  0.5333333333333333,
#  0.7333333333333333,
#  0.8,
#  0.6666666666666666,
#  0.7666666666666667,
#  0.7333333333333333,
#  0.7,
#  0.7,
#  0.7,
#  0.7333333333333333,
#  0.5333333333333333,
#  0.8,
#  0.5666666666666667,
#  0.5333333333333333,
#  0.8333333333333334,
#  0.6333333333333333,
#  0.5,
#  0.8,
#  0.7,
#  0.7,
#  0.7333333333333333,
#  0.7,
#  0.7333333333333333,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.5666666666666667,
#  0.6,
#  0.9,
#  0.5666666666666667,
#  0.6666666666666666,
#  0.6,
#  0.6666666666666666,
#  0.7,
#  0.6666666666666666,
#  0.8,
#  0.7333333333333333,
#  0.7,
#  0.6666666666666666,
#  0.6666666666666666,
#  0.7,
#  0.6666666666666666,
#  0.7,
#  0.6666666666666666,
#  0.7,
#  0.6,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.7333333333333333,
#  0.6333333333333333,
#  0.6666666666666666,
#  0.6333333333333333,
#  0.8,
#  0.6333333333333333,
#  0.8]

# %%
accuracies_500 = []

# Split the data into training and testing sets

for i in tqdm(range(1000)):
    random_44 = random.sample(list(x) , 500)

    X_train, X_test, y_train, y_test = train_test_split(outlier_corrected_combined.drop(columns='Label')[random_44], outlier_corrected_combined['Label'], test_size=0.2, random_state = 42)

    #y_train = random.sample(list(y_train), len(list(y_train)))
    #y_test = random.sample(list(y_test), len(list(y_test)))
    # Initialize and train the logistic regression model
    #scaler = StandardScaler()
    #X_train_scaled = scaler.fit_transform(X_train)
    #X_test_scaled = scaler.transform(X_test)
    model = LogisticRegression(class_weight={'AD':1,'NCI':1})
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model performance
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)
    accuracies_500.append(accuracy)
    print(accuracy)
# Out:
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   0%|                                          | 2/1000 [00:00<01:03, 15.72it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   0%|▏                                         | 4/1000 [00:00<01:06, 15.05it/s]
# 0.6666666666666666
# 0.7
# 0.7333333333333333
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▎                                         | 6/1000 [00:00<01:07, 14.77it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7666666666666667
# 0.8333333333333334
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▎                                         | 8/1000 [00:00<01:07, 14.61it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▍                                        | 10/1000 [00:00<01:08, 14.54it/s]
# 0.7333333333333333
# 0.8666666666666667
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▍                                        | 12/1000 [00:00<01:07, 14.54it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8
# 0.7666666666666667
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▌                                        | 14/1000 [00:00<01:07, 14.53it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▋                                        | 16/1000 [00:01<01:07, 14.55it/s]
# 0.7333333333333333
# 0.7333333333333333
# 0.7666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▋                                        | 18/1000 [00:01<01:07, 14.51it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6666666666666666
# 0.6666666666666666
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▊                                        | 20/1000 [00:01<01:07, 14.56it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▉                                        | 22/1000 [00:01<01:07, 14.56it/s]
# 0.7333333333333333
# 0.6666666666666666
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▉                                        | 24/1000 [00:01<01:07, 14.50it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7666666666666667
# 0.7333333333333333
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█                                        | 26/1000 [00:01<01:06, 14.55it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▏                                       | 28/1000 [00:01<01:06, 14.56it/s]
# 0.9
# 0.8333333333333334
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▏                                       | 30/1000 [00:02<01:06, 14.53it/s]
# 0.7
# 0.7333333333333333
# 0.7666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▎                                       | 32/1000 [00:02<01:06, 14.61it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▍                                       | 34/1000 [00:02<01:05, 14.65it/s]
# 0.7333333333333333
# 0.8
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▍                                       | 36/1000 [00:02<01:05, 14.63it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9
# 0.7666666666666667
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▌                                       | 38/1000 [00:02<01:05, 14.62it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▋                                       | 40/1000 [00:02<01:05, 14.58it/s]
# 0.6
# 0.8666666666666667
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▋                                       | 42/1000 [00:02<01:05, 14.54it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7333333333333333
# 0.7666666666666667
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▊                                       | 44/1000 [00:03<01:05, 14.55it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|█▉                                       | 46/1000 [00:03<01:05, 14.52it/s]
# 0.7333333333333333
# 0.8
# 0.8333333333333334
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|█▉                                       | 48/1000 [00:03<01:05, 14.53it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8
# 0.7666666666666667
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██                                       | 50/1000 [00:03<01:05, 14.55it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██▏                                      | 52/1000 [00:03<01:05, 14.56it/s]
# 0.7333333333333333
# 0.7
# 0.8333333333333334
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██▏                                      | 54/1000 [00:03<01:05, 14.53it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7
# 0.7333333333333333
# 0.8
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▎                                      | 56/1000 [00:03<01:05, 14.48it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▍                                      | 58/1000 [00:03<01:04, 14.54it/s]
# 0.8
# 0.7333333333333333
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▍                                      | 60/1000 [00:04<01:04, 14.58it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7666666666666667
# 0.7333333333333333
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▌                                      | 62/1000 [00:04<01:04, 14.60it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▌                                      | 64/1000 [00:04<01:04, 14.62it/s]
# 0.7333333333333333
# 0.6666666666666666
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▋                                      | 66/1000 [00:04<01:03, 14.60it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▊                                      | 68/1000 [00:04<01:04, 14.55it/s]
# 0.8333333333333334
# 0.7666666666666667
# 0.7333333333333333
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▊                                      | 70/1000 [00:04<01:03, 14.58it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7333333333333333
# 0.8
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▉                                      | 72/1000 [00:04<01:03, 14.59it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|███                                      | 74/1000 [00:05<01:03, 14.62it/s]
# 0.7666666666666667
# 0.7666666666666667
# 0.8
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███                                      | 76/1000 [00:05<01:03, 14.52it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7333333333333333
# 0.6666666666666666
# 0.8
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▏                                     | 78/1000 [00:05<01:03, 14.50it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▎                                     | 80/1000 [00:05<01:03, 14.56it/s]
# 0.7333333333333333
# 0.8
# 0.7666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▎                                     | 82/1000 [00:05<01:02, 14.58it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7
# 0.6666666666666666
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▍                                     | 84/1000 [00:05<01:02, 14.61it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7333333333333333
# 0.7666666666666667
# 0.8
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  97%|██████████████████████████████████████▉ | 972/1000 [01:06<00:01, 14.52it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  97%|██████████████████████████████████████▉ | 974/1000 [01:07<00:01, 14.49it/s]
# 0.7333333333333333
# 0.8
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████ | 976/1000 [01:07<00:01, 14.53it/s]
# 0.7666666666666667
# 0.8333333333333334
# 0.7666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████ | 978/1000 [01:07<00:01, 14.57it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▏| 980/1000 [01:07<00:01, 14.58it/s]
# 0.8
# 0.6666666666666666
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▎| 982/1000 [01:07<00:01, 14.57it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7
# 0.7
# 0.7666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▎| 984/1000 [01:07<00:01, 14.53it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▍| 986/1000 [01:07<00:00, 14.53it/s]
# 0.7333333333333333
# 0.8333333333333334
# 0.7666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▌| 988/1000 [01:08<00:00, 14.49it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7
# 0.7
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▌| 990/1000 [01:08<00:00, 14.50it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▋| 992/1000 [01:08<00:00, 14.49it/s]
# 0.7666666666666667
# 0.7
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▊| 994/1000 [01:08<00:00, 14.49it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7666666666666667
# 0.6666666666666666
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████▊| 996/1000 [01:08<00:00, 14.46it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████▉| 998/1000 [01:08<00:00, 14.60it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7333333333333333
# 0.7333333333333333
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████| 1000/1000 [01:08<00:00, 14.52it/s]
# 0.7666666666666667
# 0.8

# %%
accuracies_1000 = []

# Split the data into training and testing sets

for i in tqdm(range(1000)):
    random_44 = random.sample(list(x) , 1000)

    X_train, X_test, y_train, y_test = train_test_split(outlier_corrected_combined.drop(columns='Label')[random_44], outlier_corrected_combined['Label'], test_size=0.2, random_state = 42)

    #y_train = random.sample(list(y_train), len(list(y_train)))
    #y_test = random.sample(list(y_test), len(list(y_test)))
    # Initialize and train the logistic regression model
    #scaler = StandardScaler()
    #X_train_scaled = scaler.fit_transform(X_train)
    #X_test_scaled = scaler.transform(X_test)
    model = LogisticRegression(class_weight={'AD':1,'NCI':1})
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model performance
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)
    accuracies_1000.append(accuracy)
# Out:
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   0%|                                          | 2/1000 [00:00<01:08, 14.49it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   0%|▏                                         | 4/1000 [00:00<01:11, 13.89it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▎                                         | 6/1000 [00:00<01:13, 13.60it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▎                                         | 8/1000 [00:00<01:16, 12.97it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▍                                        | 10/1000 [00:00<01:15, 13.13it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▍                                        | 12/1000 [00:00<01:14, 13.21it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▌                                        | 14/1000 [00:01<01:14, 13.29it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▋                                        | 16/1000 [00:01<01:13, 13.35it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▋                                        | 18/1000 [00:01<01:13, 13.28it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▊                                        | 20/1000 [00:01<01:13, 13.30it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▉                                        | 22/1000 [00:01<01:13, 13.34it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▉                                        | 24/1000 [00:01<01:13, 13.37it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█                                        | 26/1000 [00:01<01:12, 13.38it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▏                                       | 28/1000 [00:02<01:12, 13.32it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▏                                       | 30/1000 [00:02<01:12, 13.37it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▎                                       | 32/1000 [00:02<01:12, 13.39it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▍                                       | 34/1000 [00:02<01:11, 13.43it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▍                                       | 36/1000 [00:02<01:11, 13.48it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▌                                       | 38/1000 [00:02<01:11, 13.46it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▋                                       | 40/1000 [00:02<01:11, 13.41it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▋                                       | 42/1000 [00:03<01:11, 13.44it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▊                                       | 44/1000 [00:03<01:11, 13.42it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|█▉                                       | 46/1000 [00:03<01:10, 13.45it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|█▉                                       | 48/1000 [00:03<01:10, 13.47it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██                                       | 50/1000 [00:03<01:10, 13.40it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██▏                                      | 52/1000 [00:03<01:10, 13.45it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██▏                                      | 54/1000 [00:04<01:10, 13.42it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▎                                      | 56/1000 [00:04<01:10, 13.44it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▍                                      | 58/1000 [00:04<01:10, 13.40it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▍                                      | 60/1000 [00:04<01:09, 13.45it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▌                                      | 62/1000 [00:04<01:09, 13.40it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▌                                      | 64/1000 [00:04<01:09, 13.42it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▋                                      | 66/1000 [00:04<01:09, 13.42it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▊                                      | 68/1000 [00:05<01:09, 13.46it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▊                                      | 70/1000 [00:05<01:09, 13.47it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▉                                      | 72/1000 [00:05<01:08, 13.48it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|███                                      | 74/1000 [00:05<01:08, 13.44it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███                                      | 76/1000 [00:05<01:08, 13.46it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▏                                     | 78/1000 [00:05<01:08, 13.48it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▎                                     | 80/1000 [00:05<01:08, 13.47it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▎                                     | 82/1000 [00:06<01:08, 13.49it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▍                                     | 84/1000 [00:06<01:07, 13.50it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   9%|███▌                                     | 86/1000 [00:06<01:08, 13.42it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  97%|██████████████████████████████████████▉ | 972/1000 [01:12<00:02, 13.50it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  97%|██████████████████████████████████████▉ | 974/1000 [01:12<00:01, 13.54it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████ | 976/1000 [01:12<00:01, 13.46it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████ | 978/1000 [01:12<00:01, 13.46it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▏| 980/1000 [01:12<00:01, 13.46it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▎| 982/1000 [01:13<00:01, 13.44it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▎| 984/1000 [01:13<00:01, 13.45it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▍| 986/1000 [01:13<00:01, 13.45it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▌| 988/1000 [01:13<00:00, 13.39it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▌| 990/1000 [01:13<00:00, 13.40it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▋| 992/1000 [01:13<00:00, 13.40it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▊| 994/1000 [01:13<00:00, 13.43it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████▊| 996/1000 [01:14<00:00, 13.48it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████▉| 998/1000 [01:14<00:00, 13.50it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████| 1000/1000 [01:14<00:00, 13.44it/s]

# %%
import scipy.stats as stats

# Example: Given accuracy you want to test
given_accuracy = 0.96  # Example accuracy

# Perform one-sample t-test to compare the given accuracy to the mean of the accuracies
# Null hypothesis: The given accuracy is eqaccuraciesual to the mean of the accuracies (no difference)

t_stat, p_value = stats.ttest_1samp(accuracies, given_accuracy)

# Output the t-statistic and p-value
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value}")

# Interpretation of p-value
if p_value < 0.05:
    print("The given accuracy is significantly different from the mean accuracy (reject null hypothesis).")
    print(p_value)
else:
    print("The given accuracy is not significantly different from the mean accuracy (fail to reject null hypothesis).")
# Out:
# T-statistic: -131.2262
# P-value: 0.0
# The given accuracy is significantly different from the mean accuracy (reject null hypothesis).
# 0.0

# %%
import scipy.stats as stats

# Example: Given accuracy you want to test
given_accuracy = 0.96  # Example accuracy

# Perform one-sample t-test to compare the given accuracy to the mean of the accuracies
# Null hypothesis: The given accuracy is eqaccuraciesual to the mean of the accuracies (no difference)

t_stat, p_value = stats.ttest_1samp(accuracies_100, given_accuracy)

# Output the t-statistic and p-value
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value}")

# Interpretation of p-value
if p_value < 0.05:
    print("The given accuracy is significantly different from the mean accuracy (reject null hypothesis).")
    print(p_value)
else:
    print("The given accuracy is not significantly different from the mean accuracy (fail to reject null hypothesis).")
# Out:
# T-statistic: -126.3871
# P-value: 0.0
# The given accuracy is significantly different from the mean accuracy (reject null hypothesis).
# 0.0

# %%
import scipy.stats as stats

# Example: Given accuracy you want to test
given_accuracy = 0.96  # Example accuracy

# Perform one-sample t-test to compare the given accuracy to the mean of the accuracies
# Null hypothesis: The given accuracy is eqaccuraciesual to the mean of the accuracies (no difference)

t_stat, p_value = stats.ttest_1samp(accuracies_500, given_accuracy)

# Output the t-statistic and p-value
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value}")

# Interpretation of p-value
if p_value < 0.05:
    print("The given accuracy is significantly different from the mean accuracy (reject null hypothesis).")
    print(p_value)
else:
    print("The given accuracy is not significantly different from the mean accuracy (fail to reject null hypothesis).")
# Out:
# T-statistic: -111.6795
# P-value: 0.0
# The given accuracy is significantly different from the mean accuracy (reject null hypothesis).
# 0.0

# %%
import scipy.stats as stats

# Example: Given accuracy you want to test
given_accuracy = 0.96  # Example accuracy

# Perform one-sample t-test to compare the given accuracy to the mean of the accuracies
# Null hypothesis: The given accuracy is eqaccuraciesual to the mean of the accuracies (no difference)

t_stat, p_value = stats.ttest_1samp(accuracies_1000, given_accuracy)

# Output the t-statistic and p-value
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value}")

# Interpretation of p-value
if p_value < 0.05:
    print("The given accuracy is significantly different from the mean accuracy (reject null hypothesis).")
    print(p_value)
else:
    print("The given accuracy is not significantly different from the mean accuracy (fail to reject null hypothesis).")
# Out:
# T-statistic: -130.2353
# P-value: 0.0
# The given accuracy is significantly different from the mean accuracy (reject null hypothesis).
# 0.0

# %%
import numpy as np

# Bootstrap method to compute p-value
def bootstrap_p_value(accuracies, given_accuracy, n_iter=10000):
    resampled_accuracies = np.random.choice(accuracies, (n_iter, len(accuracies)), replace=True)
    resampled_means = resampled_accuracies.mean(axis=1)
    p_value = np.mean(resampled_means >= given_accuracy)
    return p_value

# Calculate bootstrap p-value
p_value_bootstrap = bootstrap_p_value(accuracies, given_accuracy)
print(f"Bootstrap p-value: {p_value_bootstrap:.4f}")
# Out:
# Bootstrap p-value: 0.0000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example: Given accuracy you want to compare
given_accuracy = 0.96 # Example accuracy

# Create boxplot of the accuracies
plt.figure(figsize=(10, 6))
sns.boxplot(data=accuracies)

# Optionally, add a line for the given accuracy for comparison
plt.axhline(y=given_accuracy, color='r', linestyle='--', label=f"Given Accuracy: {given_accuracy}")

# Add titles and labels
plt.title('Cross-Validation Accuracy Distribution with Given Accuracy')
plt.ylabel('Accuracy')
plt.legend()

# Show the plot
plt.show()

# %%
accuracies_1000 = []

# Split the data into training and testing sets
accuracies_22 = []
for i in tqdm(range(1000)):
    random_44 = random.sample(list(x) , 22)

    X_train, X_test, y_train, y_test = train_test_split(outlier_corrected_combined.drop(columns='Label')[random_44], outlier_corrected_combined['Label'], test_size=0.2, random_state = 42)

    #y_train = random.sample(list(y_train), len(list(y_train)))
    #y_test = random.sample(list(y_test), len(list(y_test)))
    # Initialize and train the logistic regression model
    #scaler = StandardScaler()
    #X_train_scaled = scaler.fit_transform(X_train)
    #X_test_scaled = scaler.transform(X_test)
    model = LogisticRegression(class_weight={'AD':1,'NCI':1})
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model performance
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)
    accuracies_22.append(accuracy)
    print(accuracy)
# Out:
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   0%|▏                                         | 3/1000 [00:00<00:44, 22.40it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.4666666666666667
# 0.7333333333333333
# 0.6333333333333333
# 0.7333333333333333
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▎                                         | 6/1000 [00:00<00:43, 23.03it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▍                                         | 9/1000 [00:00<00:42, 23.41it/s]
# 0.5
# 0.6333333333333333
# 0.7333333333333333
# 0.5666666666666667
# 0.5333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   1%|▍                                        | 12/1000 [00:00<00:42, 23.40it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▌                                        | 15/1000 [00:00<00:42, 23.39it/s]
# 0.5666666666666667
# 0.6
# 0.7
# 0.6
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▋                                        | 18/1000 [00:00<00:41, 23.44it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.4666666666666667
# 0.6
# 0.5
# 0.5666666666666667
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▊                                        | 21/1000 [00:00<00:41, 23.51it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   2%|▉                                        | 24/1000 [00:01<00:41, 23.54it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6666666666666666
# 0.6333333333333333
# 0.5333333333333333
# 0.5666666666666667
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█                                        | 27/1000 [00:01<00:41, 23.51it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▏                                       | 30/1000 [00:01<00:41, 23.54it/s]
# 0.5666666666666667
# 0.6333333333333333
# 0.6333333333333333
# 0.5666666666666667
# 0.6
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   3%|█▎                                       | 33/1000 [00:01<00:41, 23.58it/s]
# 0.6
# 0.6666666666666666
# 0.8
# 0.5
# 0.5333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▍                                       | 36/1000 [00:01<00:40, 23.65it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▌                                       | 39/1000 [00:01<00:40, 23.68it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.5666666666666667
# 0.6
# 0.7333333333333333
# 0.6
# 0.6
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▋                                       | 42/1000 [00:01<00:40, 23.59it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   4%|█▊                                       | 45/1000 [00:01<00:40, 23.57it/s]
# 0.6666666666666666
# 0.7333333333333333
# 0.7
# 0.5333333333333333
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|█▉                                       | 48/1000 [00:02<00:40, 23.61it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.5666666666666667
# 0.6333333333333333
# 0.6
# 0.6666666666666666
# 0.7
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██                                       | 51/1000 [00:02<00:40, 23.66it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   5%|██▏                                      | 54/1000 [00:02<00:39, 23.72it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.5333333333333333
# 0.43333333333333335
# 0.7
# 0.6333333333333333
# 0.4666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▎                                      | 57/1000 [00:02<00:39, 23.80it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▍                                      | 60/1000 [00:02<00:39, 23.76it/s]
# 0.6333333333333333
# 0.6
# 0.6
# 0.7
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   6%|██▌                                      | 63/1000 [00:02<00:39, 23.70it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6
# 0.5666666666666667
# 0.6333333333333333
# 0.6
# 0.5333333333333333
#   7%|██▋                                      | 66/1000 [00:02<00:39, 23.76it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▊                                      | 69/1000 [00:02<00:39, 23.82it/s]
# 0.6
# 0.6666666666666666
# 0.5666666666666667
# 0.8333333333333334
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   7%|██▉                                      | 72/1000 [00:03<00:39, 23.79it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███                                      | 75/1000 [00:03<00:39, 23.68it/s]
# 0.43333333333333335
# 0.4666666666666667
# 0.7333333333333333
# 0.7333333333333333
# 0.5666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▏                                     | 78/1000 [00:03<00:39, 23.15it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6666666666666666
# 0.6666666666666666
# 0.6333333333333333
# 0.4666666666666667
# 0.5333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▎                                     | 81/1000 [00:03<00:39, 23.32it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   8%|███▍                                     | 84/1000 [00:03<00:39, 23.43it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.5
# 0.6666666666666666
# 0.7
# 0.6666666666666666
# 0.5666666666666667
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   9%|███▌                                     | 87/1000 [00:03<00:38, 23.45it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   9%|███▋                                     | 90/1000 [00:03<00:38, 23.49it/s]
# 0.5333333333333333
# 0.7666666666666667
# 0.5
# 0.6333333333333333
# 0.6
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#   9%|███▊                                     | 93/1000 [00:03<00:38, 23.50it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6333333333333333
# 0.5333333333333333
# 0.4666666666666667
# 0.5666666666666667
# 0.5333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  10%|███▉                                     | 96/1000 [00:04<00:38, 23.50it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  10%|████                                     | 99/1000 [00:04<00:38, 23.61it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6333333333333333
# 0.6
# 0.5333333333333333
# 0.6666666666666666
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  10%|████                                    | 102/1000 [00:04<00:38, 23.57it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  97%|██████████████████████████████████████▊ | 969/1000 [00:40<00:01, 23.66it/s]
# 0.5666666666666667
# 0.7
# 0.7333333333333333
# 0.7666666666666667
# 0.36666666666666664
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  97%|██████████████████████████████████████▉ | 972/1000 [00:41<00:01, 23.66it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████ | 975/1000 [00:41<00:01, 23.71it/s]
# 0.7
# 0.7333333333333333
# 0.7
# 0.5
# 0.6333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████ | 978/1000 [00:41<00:00, 23.70it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7
# 0.6666666666666666
# 0.6333333333333333
# 0.3333333333333333
# 0.6
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▏| 981/1000 [00:41<00:00, 23.63it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  98%|███████████████████████████████████████▎| 984/1000 [00:41<00:00, 23.60it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7
# 0.6333333333333333
# 0.6333333333333333
# 0.6
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▍| 987/1000 [00:41<00:00, 23.56it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▌| 990/1000 [00:41<00:00, 23.54it/s]
# 0.8333333333333334
# 0.6666666666666666
# 0.7666666666666667
# 0.6333333333333333
# 0.6666666666666666
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  99%|███████████████████████████████████████▋| 993/1000 [00:42<00:00, 23.54it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.5333333333333333
# 0.5666666666666667
# 0.7333333333333333
# 0.5
# 0.7333333333333333
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████▊| 996/1000 [00:42<00:00, 23.50it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████▉| 999/1000 [00:42<00:00, 23.52it/s]/home/anwer/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████| 1000/1000 [00:42<00:00, 23.64it/s]
# 0.5333333333333333
# 0.6666666666666666
# 0.7666666666666667
# 0.5
# 0.7

# %%
accuracies_1000
# Out:
# []

# %%
import seaborn as sns
import matplotlib.pyplot as plt



# Combine these accuracies into a single DataFrame for easier plotting
import pandas as pd

data = {
    'Regulations':['22'] * len(accuracies_22) +  ['100'] * len(accuracies_100) + ['500'] * len(accuracies_500) + ['1000'] * len(accuracies_1000),
    'Accuracy': accuracies_22 + accuracies_100 + accuracies_500 + accuracies_1000
}

df = pd.DataFrame(data)

# Create a boxplot to compare the distributions for 100, 200, and 300 regulations
plt.figure(figsize=(10, 8))
sns.boxplot(x='Regulations', y='Accuracy', data=df)

# Add title and labels
plt.title(' Accuracy at number of regulatory edges')
plt.xlabel('Number of regulatory edges')
plt.ylabel('Accuracy')
plt.axhline(y=0.96, color='r', linestyle='--', label=f"Accurcay on key regulatory edges: {given_accuracy}")
plt.legend()
# Show the plot
plt.ylim(0.2, 1.0) 
plt.show()
