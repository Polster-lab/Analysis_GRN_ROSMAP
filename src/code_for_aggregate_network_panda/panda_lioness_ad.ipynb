# %%
from netZooPy.panda import Panda
from netZooPy.lioness import Lioness
from netZooPy.lioness.analyze_lioness import AnalyzeLioness
import pandas as pd

# %% [markdown]
# # AD

# %%
exp_data_path = '../../data_preprocessed/grn_input/count_matrix_ad.txt'
motif_data_path = '../../data_preprocessed/grn_input/tf.txt' 
ppi_data_path = '../../data_preprocessed/grn_input/ppi.txt'

# %%
ppi_data = pd.read_csv(ppi_data_path ,header=None, sep = "\t")
ppi_data
# Out:
#                     0                1  2
# 0     ENSG00000006047  ENSG00000065978  1
# 1     ENSG00000065970  ENSG00000184486  1
# 2     ENSG00000065970  ENSG00000132005  1
# 3     ENSG00000070444  ENSG00000108788  1
# 4     ENSG00000070444  ENSG00000125952  1
# ...               ...              ... ..
# 6977  ENSG00000131408  ENSG00000112033  1
# 6978  ENSG00000185670  ENSG00000179456  1
# 6979  ENSG00000181827  ENSG00000143390  1
# 6980  ENSG00000181827  ENSG00000111783  1
# 6981  ENSG00000181827  ENSG00000132005  1
#
# [6982 rows x 3 columns]

# %%
motif_data = pd.read_csv(motif_data_path ,header=None, sep = "\t")
motif_data
# Out:
#                       0                1    2
# 0       ENSG00000106546  ENSG00000224870  1.0
# 1       ENSG00000106546  ENSG00000130770  1.0
# 2       ENSG00000106546  ENSG00000116985  1.0
# 3       ENSG00000106546  ENSG00000132854  1.0
# 4       ENSG00000106546  ENSG00000122432  1.0
# ...                 ...              ...  ...
# 698912  ENSG00000137185  ENSG00000160218  1.0
# 698913  ENSG00000137185  ENSG00000131100  1.0
# 698914  ENSG00000137185  ENSG00000178026  1.0
# 698915  ENSG00000137185  ENSG00000185666  1.0
# 698916  ENSG00000137185  ENSG00000100417  1.0
#
# [698917 rows x 3 columns]

# %%
expression_data = pd.read_csv(exp_data_path ,index_col=0, sep = "\t")
expression_data
# Out:
#                  202_120424  323_120501  550_120517   02_120405  424_120507  \
# ENSG00000101901  487.776747  352.457509  343.951603  349.968264  302.032190
# ENSG00000174839  386.519521  323.587269  350.534409  320.946506  402.162427
# ENSG00000151466  198.159304  228.556064  215.586890  341.432453  228.165622
# ENSG00000168288  394.141032  332.007756  347.243006  472.030366  336.503255
# ENSG00000112343  184.005068  122.698518  203.244129  118.647777  200.260474
# ...                     ...         ...         ...         ...         ...
# ENSG00000120457   62.060881   31.276093  106.147743   37.557570   39.395503
# ENSG00000100528  719.688460  632.739418  737.274249  739.201261  658.233196
# ENSG00000116205  383.253159  419.821401  404.019706  370.454211  485.877871
# ENSG00000100603  543.304904  572.593086  552.132836  652.989566  600.781421
# ENSG00000114933  329.902577  387.342382  411.425362  305.582045  395.596510
#
# ...

# %% [markdown]
# # Panda

# %%
panda_obj = Panda(exp_data_path,motif_data_path,ppi_data_path,
                  with_header = True,
                  remove_missing=False, 
                  keep_expression_matrix=True, save_memory=False, modeProcess='legacy')
# Out:
# Loading motif data ...
#   Elapsed time: 0.17 sec.
# Loading expression data ...
#   Elapsed time: 0.12 sec.
# Loading PPI data ...
# Number of PPIs: 6982
#   Elapsed time: 0.00 sec.
# Calculating coexpression network ...
#   Elapsed time: 1.13 sec.
# Creating motif network ...
#   Elapsed time: 0.24 sec.
# Creating PPI network ...
#   Elapsed time: 0.00 sec.
# legacy ../../data_preprocessed/grn_input/tf.txt ../../data_preprocessed/grn_input/count_matrix_ad.txt ../../data_preprocessed/grn_input/ppi.txt False False True
# Normalizing networks ...
#   Elapsed time: 7.95 sec.
# Running PANDA algorithm ...
# Computing panda on CPU
# step: 0, hamming: 0.8908395444252633
# step: 1, hamming: 0.2840030653299883
# step: 2, hamming: 0.2247717267469502
# step: 3, hamming: 0.2003534267775657
# step: 4, hamming: 0.18317511272811368
# step: 5, hamming: 0.16772984594448495
# step: 6, hamming: 0.15266726885965767
# step: 7, hamming: 0.13779624479152794
# step: 8, hamming: 0.12327818540442674
# ...

# %%
panda_output = '/12tb_dsk2/danish/GRN_new_21_feb_2025/data_preprocessed/grn_output/ad_nci_seperate_network/panda/output_panda_ad.txt'

# %%
panda_obj.save_panda_results(panda_output)
# Out:
# Saving PANDA network to /12tb_dsk2/danish/GRN_new_21_feb_2025/data_preprocessed/grn_output/ad_nci_seperate_network/panda/output_panda_ad.txt ...
# WARNING: saving without header will soon become obsolete.
#                     Use old_compatible=False to save the panda results with correct column naming
#   Elapsed time: 14.72 sec.

# %%
panda_obj.top_network_plot(top=10)
# Out:
#                        tf             gene  motif      force
# 9383979   ENSG00000153879  ENSG00000153132    1.0  32.263850
# 9384345   ENSG00000221869  ENSG00000153132    1.0  32.133680
# 11991584  ENSG00000153879  ENSG00000130770    1.0  32.099446
# 11991950  ENSG00000221869  ENSG00000130770    1.0  31.962409
# 10514518  ENSG00000172216  ENSG00000042980    1.0  31.823751
# 3741199   ENSG00000153879  ENSG00000196951    1.0  31.344816
# 3741565   ENSG00000221869  ENSG00000196951    1.0  31.320539
# 578754    ENSG00000153879  ENSG00000145088    1.0  31.163899
# 6689144   ENSG00000153879  ENSG00000103152    1.0  31.103706
# 579120    ENSG00000221869  ENSG00000145088    1.0  31.073999
# False
# /home/anwer/.local/lib/python3.12/site-packages/networkx/drawing/nx_pylab.py:450: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin' will be ignored
#   node_collection = ax.scatter(

# %%
panda_result_df = panda_obj.export_panda_results

# %%
panda_result_df = panda_result_df.sort_values(by = 'force', ascending=False)

# %%
panda_result_df
# Out:
#                        tf             gene  motif      force
# 9383979   ENSG00000153879  ENSG00000153132    1.0  32.263850
# 9384345   ENSG00000221869  ENSG00000153132    1.0  32.133680
# 11991584  ENSG00000153879  ENSG00000130770    1.0  32.099446
# 11991950  ENSG00000221869  ENSG00000130770    1.0  31.962409
# 10514518  ENSG00000172216  ENSG00000042980    1.0  31.823751
# ...                   ...              ...    ...        ...
# 3315964   ENSG00000180855  ENSG00000092148    0.0  -2.922488
# 2093314   ENSG00000180855  ENSG00000105983    0.0  -2.931945
# 11570761  ENSG00000197841  ENSG00000153823    0.0  -2.932386
# 11570482  ENSG00000162714  ENSG00000153823    0.0  -2.952556
# 11570639  ENSG00000180855  ENSG00000153823    0.0  -3.003504
#
# [12390950 rows x 4 columns]

# %%
panda_result_df.to_csv('/12tb_dsk2/danish/GRN_new_21_feb_2025/data_preprocessed/grn_output/ad_nci_seperate_network/panda/output_panda_ad_csv.csv',index = False)

# %%
panda_obj

# %% [markdown]
# # Lioness

# %%
# !mkdir /12tb_dsk2/danish/GRN_new_21_feb_2025/data_preprocessed/grn_output/ad_nci_seperate_network/lioness/ad

# %%
lioness_save_dir = '/12tb_dsk2/danish/GRN_new_21_feb_2025/data_preprocessed/grn_output/ad_nci_seperate_network/lioness/ad'

# %%
lioness_obj = Lioness(panda_obj, save_single=True, save_fmt = 'csv',save_dir = lioness_save_dir, export_filename = 'lioness_ad_combined.txt')
# Out:
# Loading input data ...
#   Elapsed time: 0.00 sec.
# Number of total samples: 87
# Number of computed samples: 87
# Number of parallel cores: 1
# Running LIONESS for sample 1:
# Computing coexpression network:
#   Elapsed time: 1.21 sec.
# Normalizing networks:
#   Elapsed time: 7.36 sec.
# Inferring LIONESS network:
# Computing panda on CPU
# step: 0, hamming: 0.8915377330973402
# step: 1, hamming: 0.28422163690349983
# step: 2, hamming: 0.22490362025064872
# step: 3, hamming: 0.20044990486295988
# step: 4, hamming: 0.18325165810531077
# step: 5, hamming: 0.16779263352993526
# step: 6, hamming: 0.15272010390727406
# step: 7, hamming: 0.13784113891637673
# step: 8, hamming: 0.12331648138814902
# step: 9, hamming: 0.10938681747218687
# step: 10, hamming: 0.09626900331717617
# step: 11, hamming: 0.08412100777861127
# step: 12, hamming: 0.07303632241558382
# step: 13, hamming: 0.06305068332296643
# step: 14, hamming: 0.05415385262308614
# step: 15, hamming: 0.04630198902385981
# ...
