# %%
from netZooPy.panda import Panda
from netZooPy.lioness import Lioness
from netZooPy.lioness.analyze_lioness import AnalyzeLioness
import pandas as pd

# %%
exp_data_path = '../../data_preprocessed/grn_input/count_matrix_ad_nci.txt'
motif_data_path = '../../data_preprocessed/grn_input/tf.txt' 
ppi_data_path = '../../data_preprocessed/grn_input/ppi.txt'

# %%
ppi_data = pd.read_csv(ppi_data_path ,header=None, sep = "\t")
ppi_data
# Out:
#                     0                1  2
# 0     ENSG00000006047  ENSG00000065978  1
# 1     ENSG00000065970  ENSG00000184486  1
# 2     ENSG00000065970  ENSG00000132005  1
# 3     ENSG00000070444  ENSG00000108788  1
# 4     ENSG00000070444  ENSG00000125952  1
# ...               ...              ... ..
# 6977  ENSG00000131408  ENSG00000112033  1
# 6978  ENSG00000185670  ENSG00000179456  1
# 6979  ENSG00000181827  ENSG00000143390  1
# 6980  ENSG00000181827  ENSG00000111783  1
# 6981  ENSG00000181827  ENSG00000132005  1
#
# [6982 rows x 3 columns]

# %%
motif_data = pd.read_csv(motif_data_path ,header=None, sep = "\t")
motif_data
# Out:
#                       0                1    2
# 0       ENSG00000106546  ENSG00000224870  1.0
# 1       ENSG00000106546  ENSG00000130770  1.0
# 2       ENSG00000106546  ENSG00000116985  1.0
# 3       ENSG00000106546  ENSG00000132854  1.0
# 4       ENSG00000106546  ENSG00000122432  1.0
# ...                 ...              ...  ...
# 698912  ENSG00000137185  ENSG00000160218  1.0
# 698913  ENSG00000137185  ENSG00000131100  1.0
# 698914  ENSG00000137185  ENSG00000178026  1.0
# 698915  ENSG00000137185  ENSG00000185666  1.0
# 698916  ENSG00000137185  ENSG00000100417  1.0
#
# [698917 rows x 3 columns]

# %%
expression_data = pd.read_csv(exp_data_path ,index_col=0, sep = "\t")
expression_data
# Out:
#                   23_120411  591_120522  691_120605  588_120522  604_120523  \
# ENSG00000101901  483.749233  428.287142  393.796510  348.370890  392.736981
# ENSG00000174839  436.934791  337.803943  359.617945  406.274499  331.265105
# ENSG00000151466  240.759987  230.947593  187.239095  221.172800  280.038543
# ENSG00000168288  323.242575  372.273733  377.450240  309.452072  409.812501
# ENSG00000112343  144.901844  135.293926  148.602457  123.401133   99.721042
# ...                     ...         ...         ...         ...         ...
# ENSG00000120457   54.616849   24.128853   74.301228   16.137071   46.445417
# ENSG00000100528  737.884775  780.740745  881.212568  673.960033  754.055003
# ENSG00000116205  458.112753  437.766334  374.478191  385.391230  382.491668
# ENSG00000100603  590.753672  558.410599  537.940893  557.203577  627.013127
# ENSG00000114933  407.954423  388.646883  349.215773  346.472412  368.831251
#
#                  545_120516  364_120502  705_120605  711_120531  602_120523  \
# ENSG00000101901  315.365572  376.066735  301.448336  392.819935  409.181322
# ENSG00000174839  398.722111  390.872512  361.087396  369.115284  355.289148
# ENSG00000151466  286.190784  255.646415  215.784960  252.849614  192.947290
# ENSG00000168288  327.869053  325.727093  384.943019  436.842859  385.229245
# ENSG00000112343  168.102354  104.627490  111.687693  145.614286  124.417735
# ...                     ...         ...         ...         ...         ...
# ENSG00000120457   87.524366   23.689243   42.289515   29.348616   52.561503
# ENSG00000100528  608.502734  704.754983  720.006098  965.117945  926.146992
# ENSG00000116205  343.151085  419.497014  391.449098  516.987156  351.297135
# ENSG00000100603  594.609978  548.800799  590.968861  574.555595  544.244425
# ENSG00000114933  357.043842  329.675300  338.316118  405.236658  493.013593
#
#                  ...   65_120417  628_120524  587_120522  283_120430  \
# ENSG00000101901  ...  296.573693  299.072257  372.140831  354.778728
# ENSG00000174839  ...  329.526326  352.018064  357.304652  284.726877
# ENSG00000151466  ...  297.891798  197.473548  223.779038  245.181478
# ENSG00000168288  ...  338.753063  307.658064  247.269655  353.648860
# ENSG00000112343  ...   67.223370  114.477419   97.671514   61.012902
# ...              ...         ...         ...         ...         ...
# ENSG00000120457  ...   27.680211   15.740645   17.308876   12.428554
# ENSG00000100528  ...  821.179603  891.492901  829.589694  767.180753
# ENSG00000116205  ...  369.069485  367.758709  589.738128  347.999517
# ENSG00000100603  ...  536.468858  569.525160  485.884873  595.440732
# ENSG00000114933  ...  289.983166  439.307096  356.068304  332.181357
#
#                  721_120531  677_120604  142_120419  120_120418  483_120515  \
# ENSG00000101901  417.815236  435.136655  359.696638  387.165725  454.480361
# ENSG00000174839  323.876911  397.298685  334.004021  399.624028  269.198605
# ENSG00000151466  200.495231  234.595414  214.533352  248.207730  171.157138
# ENSG00000168288  339.299622  402.343748  340.427175  270.249343  403.797907
# ENSG00000112343  171.051875  177.838459  160.578856  189.749539  105.519206
# ...                     ...         ...         ...         ...         ...
# ENSG00000120457   29.443356   17.657719   61.662281   25.874937   39.881275
# ENSG00000100528  601.485693  853.876857  709.116230  646.873427  957.981455
# ENSG00000116205  487.918464  426.307796  486.875092  485.873818  432.878003
# ENSG00000100603  615.506338  568.830816  503.575293  599.915208  520.949152
# ENSG00000114933  364.536783  329.190339  326.296236  390.999049  334.836536
#
#                  174_120424
# ENSG00000101901  377.965207
# ENSG00000174839  402.205256
# ENSG00000151466  249.582726
# ENSG00000168288  339.360685
# ENSG00000112343  320.507313
# ...                     ...
# ENSG00000120457   30.524506
# ENSG00000100528  716.428112
# ENSG00000116205  495.574333
# ENSG00000100603  565.601141
# ENSG00000114933  396.818578
#
# [17330 rows x 154 columns]

# %% [markdown]
# # Panda

# %%
panda_obj = Panda(exp_data_path,motif_data_path,ppi_data_path,
                  with_header = True,
                  remove_missing=False, 
                  keep_expression_matrix=True, save_memory=False, modeProcess='legacy')
# Out:
# Loading motif data ...
#   Elapsed time: 0.15 sec.
# Loading expression data ...
#   Elapsed time: 0.17 sec.
# Loading PPI data ...
# Number of PPIs: 6982
#   Elapsed time: 0.00 sec.
# Calculating coexpression network ...
#   Elapsed time: 1.06 sec.
# Creating motif network ...
#   Elapsed time: 0.23 sec.
# Creating PPI network ...
#   Elapsed time: 0.00 sec.
# legacy ../../data_preprocessed/grn_input/tf.txt ../../data_preprocessed/grn_input/count_matrix_ad_nci.txt ../../data_preprocessed/grn_input/ppi.txt False False True
# Normalizing networks ...
#   Elapsed time: 6.55 sec.
# Running PANDA algorithm ...
# Computing panda on CPU
# step: 0, hamming: 0.9152809017879605
# step: 1, hamming: 0.2934850494658804
# step: 2, hamming: 0.22993342512905404
# step: 3, hamming: 0.20366432639930138
# step: 4, hamming: 0.18545059979090686
# step: 5, hamming: 0.16934472520879984
# step: 6, hamming: 0.15382523979433232
# step: 7, hamming: 0.13862576530969142
# step: 8, hamming: 0.12386753097989346
# step: 9, hamming: 0.1097669166204343
# step: 10, hamming: 0.09652477545017288
# step: 11, hamming: 0.08428732224850927
# step: 12, hamming: 0.07313914792386257
# step: 13, hamming: 0.06310920488752883
# step: 14, hamming: 0.05418203757048519
# step: 15, hamming: 0.046309921441394855
# step: 16, hamming: 0.03942371233879067
# step: 17, hamming: 0.03344175559387034
# step: 18, hamming: 0.02827668877098609
# step: 19, hamming: 0.02384052387252481
# step: 20, hamming: 0.02004810275928558
# step: 21, hamming: 0.016819326343183137
# step: 22, hamming: 0.014080452409156936
# step: 23, hamming: 0.01176471251997364
# step: 24, hamming: 0.009812454313767552
# step: 25, hamming: 0.008170950633310053
# step: 26, hamming: 0.006794014473942298
# step: 27, hamming: 0.005641489255703817
# step: 28, hamming: 0.004678686832064557
# step: 29, hamming: 0.0038758075838828798
# step: 30, hamming: 0.0032073744678854047
# step: 31, hamming: 0.0026516983983031405
# step: 32, hamming: 0.0021903839860794305
# step: 33, hamming: 0.0018078814441717425
# step: 34, hamming: 0.0014910854379636368
# step: 35, hamming: 0.001228980539811232
# step: 36, hamming: 0.0010123303649223958
# step: 37, hamming: 0.0008334071266664686
# Running panda took: 162.12 seconds!

# %%
panda_output = '../../data_preprocessed/grn_output/ad_nci_one_network/panda/output_panda_ad_nci.txt'
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
panda_obj.save_panda_results(panda_output)
# Out:
# Saving PANDA network to ../../data_preprocessed/grn_output/ad_nci_one_network/panda/output_panda_ad_nci.txt ...
# WARNING: saving without header will soon become obsolete.
#                     Use old_compatible=False to save the panda results with correct column naming
#   Elapsed time: 15.59 sec.

# %%
panda_obj.top_network_plot(top=10)
# Out:
#                        tf             gene  motif      force
# 9383979   ENSG00000153879  ENSG00000153132    1.0  32.294784
# 9384345   ENSG00000221869  ENSG00000153132    1.0  32.165342
# 11991584  ENSG00000153879  ENSG00000130770    1.0  32.133271
# 11991950  ENSG00000221869  ENSG00000130770    1.0  31.995963
# 10514518  ENSG00000172216  ENSG00000042980    1.0  31.841223
# 3741199   ENSG00000153879  ENSG00000196951    1.0  31.442711
# 3741565   ENSG00000221869  ENSG00000196951    1.0  31.416626
# 578754    ENSG00000153879  ENSG00000145088    1.0  31.221826
# 579120    ENSG00000221869  ENSG00000145088    1.0  31.128940
# 6689144   ENSG00000153879  ENSG00000103152    1.0  31.057385
# False
# /home/anwer/.local/lib/python3.12/site-packages/networkx/drawing/nx_pylab.py:450: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin' will be ignored
#   node_collection = ax.scatter(

# %%
panda_result_df = panda_obj.export_panda_results

# %%
panda_result_df = panda_result_df.sort_values(by = 'force', ascending=False)

# %%
panda_result_df
# Out:
#                        tf             gene  motif      force
# 9383979   ENSG00000153879  ENSG00000153132    1.0  32.294784
# 9384345   ENSG00000221869  ENSG00000153132    1.0  32.165342
# 11991584  ENSG00000153879  ENSG00000130770    1.0  32.133271
# 11991950  ENSG00000221869  ENSG00000130770    1.0  31.995963
# 10514518  ENSG00000172216  ENSG00000042980    1.0  31.841223
# ...                   ...              ...    ...        ...
# 11570639  ENSG00000180855  ENSG00000153823    0.0  -3.174089
# 1645567   ENSG00000162714  ENSG00000075568    0.0  -3.174844
# 3315964   ENSG00000180855  ENSG00000092148    0.0  -3.183269
# 5766269   ENSG00000180855  ENSG00000136052    0.0  -3.189118
# 1645724   ENSG00000180855  ENSG00000075568    0.0  -3.198892
#
# [12390950 rows x 4 columns]

# %%
panda_result_df.to_csv('../../data_preprocessed/grn_output/ad_nci_one_network/panda/output_panda_ad_nci_csv.csv',index = False)

# %%
panda_obj.

# %% [markdown]
# # Lioness

# %%
lioness_save_dir = '../../data_preprocessed/grn_output/ad_nci_one_network/lioness/'

# %%
lioness_obj = Lioness(panda_obj, save_single=True, save_fmt = 'csv',save_dir = lioness_save_dir, export_filename = 'lioness_combined.txt',)
# Out:
# Loading input data ...
#   Elapsed time: 0.00 sec.
# Number of total samples: 154
# Number of computed samples: 154
# Number of parallel cores: 1
# Running LIONESS for sample 1:
# Computing coexpression network:
#   Elapsed time: 1.07 sec.
# Normalizing networks:
#   Elapsed time: 6.56 sec.
# Inferring LIONESS network:
# Computing panda on CPU
# step: 0, hamming: 0.9156986536552294
# step: 1, hamming: 0.293670942568193
# step: 2, hamming: 0.23002240181070224
# step: 3, hamming: 0.2037107401017704
# step: 4, hamming: 0.18547467126295458
# step: 5, hamming: 0.16935617664038322
# step: 6, hamming: 0.15382931287103957
# step: 7, hamming: 0.13862540370907098
# step: 8, hamming: 0.12386456745248625
# step: 9, hamming: 0.1097624873507038
# step: 10, hamming: 0.09651966919149244
# step: 11, hamming: 0.08428201869321775
# step: 12, hamming: 0.07313395175843404
# step: 13, hamming: 0.06310428566061174
# step: 14, hamming: 0.05417750797184641
# step: 15, hamming: 0.04630582556240283
# step: 16, hamming: 0.03942005736213896
# step: 17, hamming: 0.03343852982178661
# step: 18, hamming: 0.02827386926549315
# step: 19, hamming: 0.023838081188348088
# step: 20, hamming: 0.020045999595217957
# step: 21, hamming: 0.016817524164605305
# step: 22, hamming: 0.014078915273103579
# step: 23, hamming: 0.011763407398668853
# step: 24, hamming: 0.009811349991312236
# step: 25, hamming: 0.008170019048723005
# step: 26, hamming: 0.0067932305838502
# step: 27, hamming: 0.005640831610796754
# step: 28, hamming: 0.0046781363847957225
# step: 29, hamming: 0.003875347684787171
# step: 30, hamming: 0.003206990907529397
# step: 31, hamming: 0.0026513789847960284
# step: 32, hamming: 0.002190118400367635
# step: 33, hamming: 0.001807660901976744
# step: 34, hamming: 0.0014909025293124963
# step: 35, hamming: 0.0012288290199130357
# step: 36, hamming: 0.0010122049792245793
# step: 37, hamming: 0.0008333034737617789
#   Elapsed time: 181.67 sec.
# Saving LIONESS network 0 (23_120411) to ../../data_preprocessed/grn_output/ad_nci_one_network/lioness/ using csv format:
# ../../data_preprocessed/grn_output/ad_nci_one_network/lioness/lioness.23_120411.0.csv
#   Elapsed time: 10.43 sec.
# Running LIONESS for sample 2:
# Computing coexpression network:
#   Elapsed time: 1.37 sec.
# Normalizing networks:
#   Elapsed time: 7.72 sec.
# Inferring LIONESS network:
# Computing panda on CPU
# step: 0, hamming: 0.9149635075628381
# step: 1, hamming: 0.29348243825964104
# step: 2, hamming: 0.22993284066631
# step: 3, hamming: 0.20366461942371733
# step: 4, hamming: 0.1854513773664575
# step: 5, hamming: 0.16934564472710512
# step: 6, hamming: 0.1538260586415043
# step: 7, hamming: 0.13862639592933163
# step: 8, hamming: 0.12386797424292528
# step: 9, hamming: 0.1097671293900325
# step: 10, hamming: 0.0965247713732258
# step: 11, hamming: 0.08428718973412824
# step: 12, hamming: 0.07313891873664075
# step: 13, hamming: 0.06310892002071329
# step: 14, hamming: 0.054181721776966944
# step: 15, hamming: 0.04630958870187526
# step: 16, hamming: 0.03942338359990811
# step: 17, hamming: 0.033441445527352356
# step: 18, hamming: 0.028276409718308575
# step: 19, hamming: 0.023840276175761968
# step: 20, hamming: 0.0200478854491
# step: 21, hamming: 0.016819135859561702
# step: 22, hamming: 0.014080286712568703
# step: 23, hamming: 0.011764570291012532
# step: 24, hamming: 0.009812332817355907
# step: 25, hamming: 0.008170847840707093
# step: 26, hamming: 0.006793927693026368
# step: 27, hamming: 0.005641416732431684
# step: 28, hamming: 0.004678626473786386
# step: 29, hamming: 0.0038757575878410598
# step: 30, hamming: 0.0032073330653917564
# step: 31, hamming: 0.002651664122003268
# step: 32, hamming: 0.0021903556769625396
# step: 33, hamming: 0.0018078580879730593
# step: 34, hamming: 0.0014910661769805206
# step: 35, hamming: 0.001228964691795807
# step: 36, hamming: 0.0010123173354506469
# step: 37, hamming: 0.0008333964224029277
#   Elapsed time: 176.64 sec.
# Saving LIONESS network 1 (591_120522) to ../../data_preprocessed/grn_output/ad_nci_one_network/lioness/ using csv format:
# ../../data_preprocessed/grn_output/ad_nci_one_network/lioness/lioness.591_120522.1.csv
#   Elapsed time: 9.61 sec.
# Running LIONESS for sample 3:
# Computing coexpression network:
#   Elapsed time: 1.08 sec.
# Normalizing networks:
#   Elapsed time: 6.60 sec.
# Inferring LIONESS network:
# Computing panda on CPU
# step: 0, hamming: 0.9151322703838553
# step: 1, hamming: 0.29353397065185455
# step: 2, hamming: 0.22994435340084463
# step: 3, hamming: 0.2036616601142148
# step: 4, hamming: 0.1854407714414372
# step: 5, hamming: 0.16933092131668806
# step: 6, hamming: 0.15380928484568604
# step: 7, hamming: 0.1386087556744565
# step: 8, hamming: 0.1238503174605205
# step: 9, hamming: 0.10975009280787437
# step: 10, hamming: 0.09650868040025623
# step: 11, hamming: 0.08427233521218681
# step: 12, hamming: 0.0731253937161451
# step: 13, hamming: 0.06309675274935134
# step: 14, hamming: 0.05417090767800264
# step: 15, hamming: 0.04630009394829438
# step: 16, hamming: 0.03941512499045398
# step: 17, hamming: 0.03343429062153304
# step: 18, hamming: 0.028270245851769064
# step: 19, hamming: 0.02383499853388274
# step: 20, hamming: 0.02004339096414469
# step: 21, hamming: 0.01681532207157435
# step: 22, hamming: 0.014077061401082737
# step: 23, hamming: 0.011761852655770996
# step: 24, hamming: 0.009810049821688697
# step: 25, hamming: 0.008168935370126843
# step: 26, hamming: 0.006792329137242281
# step: 27, hamming: 0.00564008306028589
# step: 28, hamming: 0.0046775157776239125
# step: 29, hamming: 0.0038748338925713877
# step: 30, hamming: 0.0032065661115247795
# step: 31, hamming: 0.002651028167872685
# step: 32, hamming: 0.002189828980387717
# step: 33, hamming: 0.0018074223505875893
# step: 34, hamming: 0.0014907060617509434
# step: 35, hamming: 0.001228667343092442
# step: 36, hamming: 0.0010120720010656674
# step: 37, hamming: 0.0008331941449619393
#   Elapsed time: 214.70 sec.
# Saving LIONESS network 2 (691_120605) to ../../data_preprocessed/grn_output/ad_nci_one_network/lioness/ using csv format:
# ../../data_preprocessed/grn_output/ad_nci_one_network/lioness/lioness.691_120605.2.csv
#   Elapsed time: 12.07 sec.
# Running LIONESS for sample 4:
# Computing coexpression network:
#   Elapsed time: 1.61 sec.
# Normalizing networks:
#   Elapsed time: 8.81 sec.
# Inferring LIONESS network:
# Computing panda on CPU
# step: 0, hamming: 0.9154100481844397
# step: 1, hamming: 0.29356869653192125
# step: 2, hamming: 0.2299976160107168
# step: 3, hamming: 0.20372415280583483
# step: 4, hamming: 0.1855081756546595
# step: 5, hamming: 0.16939949456104952
# step: 6, hamming: 0.1538763252068597
# step: 7, hamming: 0.13867263335240057
# step: 8, hamming: 0.12390988333584761
# step: 9, hamming: 0.10980472248979928
# step: 10, hamming: 0.09655818543340154
# step: 11, hamming: 0.08431659453231256
# step: 12, hamming: 0.0731646174987369
# step: 13, hamming: 0.06313123753266106
# step: 14, hamming: 0.05420099103875341
# step: 15, hamming: 0.04632614225093118
# step: 16, hamming: 0.039437541661368175
# step: 17, hamming: 0.03345350144673198
# step: 18, hamming: 0.02828663482899991
# step: 19, hamming: 0.02384892466122795
# step: 20, hamming: 0.02005517902503605
# step: 21, hamming: 0.016825271508436608
# step: 22, hamming: 0.014085437146509481
# step: 23, hamming: 0.011768884623329692
# step: 24, hamming: 0.009815940527465778
# step: 25, hamming: 0.00817385897592494
# step: 26, hamming: 0.006796436963893501
# step: 27, hamming: 0.005643504544243519
# step: 28, hamming: 0.004680361189970288
# step: 29, hamming: 0.0038771969287696847
# step: 30, hamming: 0.0032085261287306305
# step: 31, hamming: 0.0026526520890794124
# step: 32, hamming: 0.0021911729661169667
# step: 33, hamming: 0.0018085335603216382
# step: 34, hamming: 0.0014916239985720728
# step: 35, hamming: 0.001229425015999231
# step: 36, hamming: 0.001012696924107405
# step: 37, hamming: 0.000833709221266351
#   Elapsed time: 222.95 sec.
# Saving LIONESS network 3 (588_120522) to ../../data_preprocessed/grn_output/ad_nci_one_network/lioness/ using csv format:
# ../../data_preprocessed/grn_output/ad_nci_one_network/lioness/lioness.588_120522.3.csv
#   Elapsed time: 11.11 sec.
# Running LIONESS for sample 5:
# Computing coexpression network:
#   Elapsed time: 1.47 sec.
# Normalizing networks:
#   Elapsed time: 8.04 sec.
# Inferring LIONESS network:
# Computing panda on CPU
# step: 0, hamming: 0.9159916628012308
# step: 1, hamming: 0.29358447422094097
# step: 2, hamming: 0.2299976705399536
# step: 3, hamming: 0.20372579396282595
# step: 4, hamming: 0.18550979906113407
# step: 5, hamming: 0.16940031064745767
# step: 6, hamming: 0.15387608685005388
# step: 7, hamming: 0.13867126763411822
# step: 8, hamming: 0.12390759316746794
# step: 9, hamming: 0.1098018645945719
# step: 10, hamming: 0.09655497501236006
# step: 11, hamming: 0.08431326531937734
# step: 12, hamming: 0.07316131097854599
# step: 13, hamming: 0.0631280591450055
# step: 14, hamming: 0.05419802450293588
# step: 15, hamming: 0.046323435256635445
# step: 16, hamming: 0.03943510742599366
# step: 17, hamming: 0.03345134159478447
# step: 18, hamming: 0.028284734520788692
# step: 19, hamming: 0.023847267490366683
# step: 20, hamming: 0.02005374394328185
# step: 21, hamming: 0.016824037160063036
# step: 22, hamming: 0.01408438149947594
# step: 23, hamming: 0.011767986166821771
# step: 24, hamming: 0.009815178072152316
# step: 25, hamming: 0.0081732143352605
# step: 26, hamming: 0.006795893329540807
# step: 27, hamming: 0.005643047352140639
# step: 28, hamming: 0.0046799776844284385
# step: 29, hamming: 0.003876875973117156
# step: 30, hamming: 0.003208257938587824
# step: 31, hamming: 0.002652428400103265
# step: 32, hamming: 0.0021909867759580003
# step: 33, hamming: 0.001808378806790415
# step: 34, hamming: 0.0014914955284159794
# step: 35, hamming: 0.0012293184757030133
# step: 36, hamming: 0.0010126086923528401
# step: 37, hamming: 0.0008336362316338009
#   Elapsed time: 224.99 sec.
# Saving LIONESS network 4 (604_120523) to ../../data_preprocessed/grn_output/ad_nci_one_network/lioness/ using csv format:
# ../../data_preprocessed/grn_output/ad_nci_one_network/lioness/lioness.604_120523.4.csv
#   Elapsed time: 10.94 sec.
# Running LIONESS for sample 6:
# Computing coexpression network:
